# %%
# !nvidia-smi
# Out:
# Sun Jan 29 20:59:02 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.119.04   Driver Version: 450.119.04   CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   35C    P0    53W / 163W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:0B:00.0 Off |                    0 |
# | N/A   34C    P0    43W / 163W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import cudf
import glob
import gc

import pandas as pd

from tqdm import tqdm

# %%
def calc_recall(sub, ty='clicks', file='./data/xgb_train_y.parquet'):
    sub = sub.sort_values(['session', 'score'], ascending=[True, False])
    sub['dummy'] = 1
    sub['rank'] = sub.groupby(['session']).dummy.cumsum()
    sub.drop(['dummy'], axis=1, inplace=True)
    sub = sub[sub['rank']<21]
    sub = sub[['session', 'cand']]
    sub.columns = ['session', 'aid']
    test_labels = cudf.read_parquet(file)
    test_labels = test_labels[test_labels['type']==ty]
    test_labels = test_labels.merge(
        test_labels.groupby(['session', 'type']).count().reset_index().rename(columns={'aid': 'no_gt'}),
        how='left',
        on=['session', 'type']
    )
    sub['target'] = 1
    sub.columns = ['session', 'aid', 'target']
    test_labels = test_labels.merge(
        sub[['session', 'aid', 'target']].drop_duplicates(['session', 'aid']),
        how='left',
        on=['session', 'aid']

    )
    test_labels['target'] = test_labels['target'].fillna(0)
    test_labels = test_labels[test_labels['session'].isin(sub['session'])]
    test_labels = test_labels.groupby(['session', 'aid']).agg({'no_gt': 'min', 'target': 'sum'}).reset_index()
    recall = test_labels.target.sum()/test_labels.groupby(['session']).no_gt.min().clip(0,20).sum()
    print(recall)
    return(recall, test_labels.target.sum(), test_labels.groupby(['session']).no_gt.min().clip(0,20).sum())

# %%
# !ls ./data/split/chunks
# Out:
# carts  clicks  orders

# %%
import xgboost as xgb

xgb_parms = { 
    'max_depth':8, 
    'learning_rate':0.1, 
    'subsample':0.8,
    'colsample_bytree':0.3, 
    'eval_metric':'logloss',
    'objective':'binary:logistic',
    'tree_method':'gpu_hist' 
}

bl_sub = True
bl_pos = True
outputfolder = '24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5'
no_seeds = 10
no_trees = 377
if not bl_sub:
    no_trees = 1000

# %%
ty = 'carts'
labels = cudf.read_parquet('./data/xgb_train_y.parquet')
labels.columns = ['session', 'cand', 'type']
labels['target'] = 1

# %%
files = sorted(glob.glob('./data/split/chunks/' + ty + '/chunk*.parquet'))
files
# Out:
# []

# %%
[y for x in [
    sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
    for igfold2 in range(0,5)
] for y in x ]
# Out:
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet',
#  './data_folds/fold_0/split/chunks/carts/chunk_1.parquet',
#  './data_folds/fold_1/split/chunks/carts/chunk_0.parquet',
#  './data_folds/fold_1/split/chunks/carts/chunk_1.parquet',
#  './data_folds/fold_2/split/chunks/carts/chunk_0.parquet',
#  './data_folds/fold_2/split/chunks/carts/chunk_1.parquet',
#  './data_folds/fold_3/split/chunks/carts/chunk_0.parquet',
#  './data_folds/fold_3/split/chunks/carts/chunk_1.parquet',
#  './data_folds/fold_4/split/chunks/carts/chunk_0.parquet',
#  './data_folds/fold_4/split/chunks/carts/chunk_1.parquet']

# %%
ingore_cols = []

# %%
# %%time

if not bl_sub:
    # Local CV run
    # Predict each fold (total 10) by using 2 other folds
    model_bests = []
    hist_recall = []
    total_no_hit = 0
    total_no_gt = 0
    for igfold in range(5):
        files = sorted(glob.glob('./data_folds/fold_' + str(igfold) + '/split/chunks/' + ty + '/chunk*.parquet'))
        print(files)
        for ifile, file in enumerate(files):
            if bl_sub:
                if ty == 'clicks':
                    test_files = []
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
                elif ty == 'carts':
                    test_files = []
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
                elif ty == 'orders':
                    test_files = []
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
                else:
                    assert 0!=0
                if ty == 'clicks':
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
                elif ty == 'carts':
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
                elif ty == 'orders':
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
            else:
                if ty == 'clicks':
                    test_files = files[ifile]
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
                elif ty == 'carts':
                    test_files = files[ifile]
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
                elif ty == 'orders':
                    test_files = files[ifile]
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
                else:
                    assert 0!=0

                if ty == 'clicks':
                    train_files = [
                        y for x in [
                            sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
                            for igfold2 in range(0,5)
                        ] for y in x if y not in test_files][0:6]
                elif ty == 'carts':
                    train_files = [
                        y for x in [
                            sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
                            for igfold2 in range(0,5)
                        ] for y in x if y not in test_files][0:5]
                else:
                    train_files = [
                        y for x in [
                            sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
                            for igfold2 in range(0,5)
                        ] for y in x if y not in test_files]

                if ty == 'clicks':
                    df_test = pd.read_parquet(test_files)
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
                elif ty == 'carts':
                    df_test = pd.read_parquet(test_files)
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
                elif ty == 'orders':
                    df_test = pd.read_parquet(test_files)
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])

            print(train_files)
            print(test_files)

            if bl_pos and ty!='clicks':
                df_train = df_train[df_train['session'].isin(
                    df_train[df_train['target']==1]['session'].drop_duplicates().values
                )]

            print(df_train.shape)

            train_cols = [x for x in df_train.columns if x not in [
                'session', 'cand', 'target', 'target_clicks', 'target_carts', 'target_orders'
            ] + ingore_cols]

            print('Recall Train: ' + str(df_train[df_train['target']==1].shape[0]/labels[
            (labels['session'].isin(df_train['session'].drop_duplicates()))&(labels['type']==ty)
        ].shape[0]))
            if not bl_sub:
                print('Recall Test: ' + str(df_test[df_test['target']==1].shape[0]/labels[
                (labels['session'].isin(df_test['session'].drop_duplicates()))&(labels['type']==ty)
            ].shape[0]))

            dtrain = xgb.DMatrix(data=df_train[train_cols].values,label=df_train['target'].values)
            if not bl_sub:
                dtest =  xgb.DMatrix(data=df_test[train_cols].values, label=df_test['target'].values)
                df_test['score'] = 0.0

            del df_train
            gc.collect()

            models = []
            for iseed in range(no_seeds):
                print('iseed: ' + str(iseed))
                xgb_parms['seed'] = iseed
                if bl_sub:
                    model = xgb.train(
                        xgb_parms, 
                        dtrain=dtrain,
                        evals=[(dtrain,'train')],
                        num_boost_round=no_trees,
                        verbose_eval=10
                    )
                else:
                    model = xgb.train(
                        xgb_parms, 
                        dtrain=dtrain,
                        evals=[(dtest,'test')],
                        num_boost_round=no_trees,
                        verbose_eval=10,
                        early_stopping_rounds=50
                    )
                    df_test['score'] += model.predict(dtest)
                    model_bests.append(model.best_iteration)
                models.append(model)
            del dtrain

            if bl_sub:
                for isubfile, sub_file in enumerate(glob.glob('./data/split/sub/*.parquet')):
                    print('isubfile: ' + str(isubfile))
                    df_sub = cudf.read_parquet(sub_file)
                    df_sub['score'] = 0.0
                    dsub = xgb.DMatrix(data=df_sub[train_cols].values)
                    for iseed in range(no_seeds):
                        df_sub['score_' + str(iseed)] = models[iseed].predict(dsub)
                    iseed = 0
                    os.system('mkdir -p ../00_submissions/' + outputfolder)
                    df_sub[['session', 'cand'] + ['score_' + str(ij) for ij in range(no_seeds)]].to_parquet(
                        '../00_submissions/' + outputfolder + '/sub_' + str(iseed) + '_' + ty + '_' + str(ifile) + '_' + str(isubfile) + '.parquet'
                    )
                    del df_sub
                    gc.collect()
                del model
                gc.collect()
                break


            sub = cudf.from_pandas(df_test[['session', 'cand', 'score']])
            recall, no_hit, no_gt = calc_recall(sub, ty=ty)
            hist_recall.append(recall)
            total_no_hit += no_hit
            total_no_gt += no_gt
            print(total_no_hit/total_no_gt)

            del sub
            gc.collect()
# Out:
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet', './data_folds/fold_2/split/chunks/carts/chunk_1.parquet']
# ./data_folds/fold_0/split/chunks/carts/chunk_0.parquet
# (17881217, 171)
# Recall Train: 0.6969225848865515
# Recall Test: 0.5573679696991353
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.18999
# [20]	test-logloss:0.07920
# [30]	test-logloss:0.04315
# [40]	test-logloss:0.03109
# [50]	test-logloss:0.02715
# [60]	test-logloss:0.02589
# [70]	test-logloss:0.02546
# [80]	test-logloss:0.02527
# [90]	test-logloss:0.02518
# [100]	test-logloss:0.02513
# [110]	test-logloss:0.02510
# [120]	test-logloss:0.02508
# [130]	test-logloss:0.02506
# [140]	test-logloss:0.02505
# [150]	test-logloss:0.02503
# [160]	test-logloss:0.02503
# [170]	test-logloss:0.02502
# [180]	test-logloss:0.02501
# [190]	test-logloss:0.02500
# [200]	test-logloss:0.02500
# [210]	test-logloss:0.02499
# [220]	test-logloss:0.02499
# [230]	test-logloss:0.02499
# [240]	test-logloss:0.02498
# [250]	test-logloss:0.02498
# [260]	test-logloss:0.02498
# [270]	test-logloss:0.02498
# [280]	test-logloss:0.02498
# [290]	test-logloss:0.02497
# [300]	test-logloss:0.02497
# [310]	test-logloss:0.02497
# [320]	test-logloss:0.02497
# [330]	test-logloss:0.02497
# [340]	test-logloss:0.02497
# [350]	test-logloss:0.02497
# [360]	test-logloss:0.02497
# [370]	test-logloss:0.02496
# [380]	test-logloss:0.02496
# [390]	test-logloss:0.02496
# [400]	test-logloss:0.02496
# [410]	test-logloss:0.02497
# [420]	test-logloss:0.02497
# [425]	test-logloss:0.02497
# iseed: 1
# [0]	test-logloss:0.60046
# [10]	test-logloss:0.19008
# [20]	test-logloss:0.07922
# [30]	test-logloss:0.04315
# [40]	test-logloss:0.03109
# [50]	test-logloss:0.02718
# [60]	test-logloss:0.02591
# [70]	test-logloss:0.02546
# [80]	test-logloss:0.02528
# [90]	test-logloss:0.02520
# [100]	test-logloss:0.02514
# [110]	test-logloss:0.02511
# [120]	test-logloss:0.02509
# [130]	test-logloss:0.02506
# [140]	test-logloss:0.02505
# [150]	test-logloss:0.02503
# [160]	test-logloss:0.02502
# [170]	test-logloss:0.02502
# [180]	test-logloss:0.02501
# [190]	test-logloss:0.02500
# [200]	test-logloss:0.02500
# [210]	test-logloss:0.02499
# [220]	test-logloss:0.02499
# [230]	test-logloss:0.02499
# [240]	test-logloss:0.02498
# [250]	test-logloss:0.02498
# [260]	test-logloss:0.02498
# [270]	test-logloss:0.02497
# [280]	test-logloss:0.02497
# iseed: 1
# [0]	test-logloss:0.60047
# [10]	test-logloss:0.19009
# [20]	test-logloss:0.07924
# [30]	test-logloss:0.04317
# [40]	test-logloss:0.03113
# [50]	test-logloss:0.02723
# [60]	test-logloss:0.02598
# [70]	test-logloss:0.02554
# [80]	test-logloss:0.02536
# [90]	test-logloss:0.02528
# [100]	test-logloss:0.02522
# [110]	test-logloss:0.02518
# [120]	test-logloss:0.02516
# [130]	test-logloss:0.02514
# [140]	test-logloss:0.02513
# [150]	test-logloss:0.02511
# [160]	test-logloss:0.02510
# [170]	test-logloss:0.02510
# [180]	test-logloss:0.02509
# [190]	test-logloss:0.02509
# [200]	test-logloss:0.02508
# [210]	test-logloss:0.02507
# [220]	test-logloss:0.02507
# [230]	test-logloss:0.02507
# [240]	test-logloss:0.02507
# [250]	test-logloss:0.02507
# [260]	test-logloss:0.02507
# [270]	test-logloss:0.02507
# [280]	test-logloss:0.02506
# [290]	test-logloss:0.02506
# [300]	test-logloss:0.02506
# [310]	test-logloss:0.02506
# [320]	test-logloss:0.02506
# [330]	test-logloss:0.02506
# [340]	test-logloss:0.02506
# [350]	test-logloss:0.02506
# [360]	test-logloss:0.02506
# [363]	test-logloss:0.02506
# iseed: 2
# [0]	test-logloss:0.60043
# [10]	test-logloss:0.19004
# [20]	test-logloss:0.07922
# [30]	test-logloss:0.04315
# [40]	test-logloss:0.03113
# [50]	test-logloss:0.02721
# [60]	test-logloss:0.02594
# [70]	test-logloss:0.02551
# [80]	test-logloss:0.02535
# [90]	test-logloss:0.02526
# [100]	test-logloss:0.02521
# [110]	test-logloss:0.02518
# [120]	test-logloss:0.02516
# [130]	test-logloss:0.02514
# [140]	test-logloss:0.02513
# [150]	test-logloss:0.02512
# [160]	test-logloss:0.02511
# [170]	test-logloss:0.02510
# [180]	test-logloss:0.02509
# [190]	test-logloss:0.02509
# [200]	test-logloss:0.02509
# [210]	test-logloss:0.02508
# [220]	test-logloss:0.02508
# [230]	test-logloss:0.02507
# [240]	test-logloss:0.02507
# [250]	test-logloss:0.02507
# [260]	test-logloss:0.02507
# [270]	test-logloss:0.02507
# [280]	test-logloss:0.02506
# [290]	test-logloss:0.02506
# [300]	test-logloss:0.02506
# [310]	test-logloss:0.02506
# [320]	test-logloss:0.02506
# [330]	test-logloss:0.02506
# [340]	test-logloss:0.02507
# [350]	test-logloss:0.02507
# [360]	test-logloss:0.02507
# [370]	test-logloss:0.02507
# [371]	test-logloss:0.02507
# 0.4440682747919312
# 0.44677899791046105
# ['./data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet', './data_folds/fold_2/split/chunks/carts/chunk_1.parquet']
# ./data_folds/fold_1/split/chunks/carts/chunk_0.parquet
# (17904613, 171)
# Recall Train: 0.6969613492871012
# Recall Test: 0.5506612590372069
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.18999
# [20]	test-logloss:0.07922
# [30]	test-logloss:0.04317
# [40]	test-logloss:0.03111
# [50]	test-logloss:0.02717
# [60]	test-logloss:0.02590
# [70]	test-logloss:0.02548
# [80]	test-logloss:0.02530
# [90]	test-logloss:0.02521
# [100]	test-logloss:0.02517
# [110]	test-logloss:0.02514
# [120]	test-logloss:0.02511
# [130]	test-logloss:0.02510
# [140]	test-logloss:0.02508
# [150]	test-logloss:0.02507
# [160]	test-logloss:0.02506
# [170]	test-logloss:0.02505
# [180]	test-logloss:0.02504
# [190]	test-logloss:0.02504
# [200]	test-logloss:0.02503
# [210]	test-logloss:0.02503
# [220]	test-logloss:0.02502
# [230]	test-logloss:0.02502
# [240]	test-logloss:0.02502
# [250]	test-logloss:0.02501
# [260]	test-logloss:0.02501
# [270]	test-logloss:0.02501
# [280]	test-logloss:0.02501
# [290]	test-logloss:0.02500
# [300]	test-logloss:0.02500
# [310]	test-logloss:0.02500
# [320]	test-logloss:0.02500
# [330]	test-logloss:0.02500
# [340]	test-logloss:0.02500
# [350]	test-logloss:0.02500
# [360]	test-logloss:0.02500
# [370]	test-logloss:0.02500
# [372]	test-logloss:0.02500
# iseed: 1
# [0]	test-logloss:0.60047
# [10]	test-logloss:0.19008
# [20]	test-logloss:0.07924
# [30]	test-logloss:0.04316
# [40]	test-logloss:0.03110
# [50]	test-logloss:0.02718
# [60]	test-logloss:0.02592
# [70]	test-logloss:0.02547
# [80]	test-logloss:0.02530
# [90]	test-logloss:0.02521
# [100]	test-logloss:0.02516
# [110]	test-logloss:0.02513
# [120]	test-logloss:0.02510
# [130]	test-logloss:0.02508
# [140]	test-logloss:0.02507
# [150]	test-logloss:0.02505
# [160]	test-logloss:0.02504
# [170]	test-logloss:0.02504
# [180]	test-logloss:0.02503
# [190]	test-logloss:0.02502
# [200]	test-logloss:0.02502
# [210]	test-logloss:0.02501
# [220]	test-logloss:0.02501
# [230]	test-logloss:0.02501
# [240]	test-logloss:0.02500
# [250]	test-logloss:0.02500
# [260]	test-logloss:0.02500
# [270]	test-logloss:0.02500
# [280]	test-logloss:0.02499
# [290]	test-logloss:0.02499
# [300]	test-logloss:0.02499
# [310]	test-logloss:0.02499
# [320]	test-logloss:0.02499
# [330]	test-logloss:0.02498
# [340]	test-logloss:0.02498
# [350]	test-logloss:0.02498
# [360]	test-logloss:0.02498
# [370]	test-logloss:0.02498
# [380]	test-logloss:0.02498
# [390]	test-logloss:0.02498
# [400]	test-logloss:0.02498
# [410]	test-logloss:0.02498
# [420]	test-logloss:0.02498
# [423]	test-logloss:0.02498
# iseed: 2
# [0]	test-logloss:0.60043
# [10]	test-logloss:0.19004
# [20]	test-logloss:0.07921
# [30]	test-logloss:0.04314
# [40]	test-logloss:0.03111
# [50]	test-logloss:0.02718
# [60]	test-logloss:0.02590
# [70]	test-logloss:0.02546
# [80]	test-logloss:0.02530
# [90]	test-logloss:0.02521
# [100]	test-logloss:0.02516
# [110]	test-logloss:0.02513
# [120]	test-logloss:0.02511
# [130]	test-logloss:0.02509
# [140]	test-logloss:0.02508
# [150]	test-logloss:0.02507
# [160]	test-logloss:0.02505
# [170]	test-logloss:0.02505
# [180]	test-logloss:0.02504
# [190]	test-logloss:0.02504
# [200]	test-logloss:0.02503
# [210]	test-logloss:0.02503
# [220]	test-logloss:0.02502
# [230]	test-logloss:0.02502
# [240]	test-logloss:0.02502
# [250]	test-logloss:0.02501
# [260]	test-logloss:0.02501
# [270]	test-logloss:0.02501
# [280]	test-logloss:0.02501
# [290]	test-logloss:0.02500
# [300]	test-logloss:0.02500
# [310]	test-logloss:0.02500
# [320]	test-logloss:0.02500
# [330]	test-logloss:0.02500
# [340]	test-logloss:0.02500
# [350]	test-logloss:0.02500
# [360]	test-logloss:0.02500
# [370]	test-logloss:0.02500
# [380]	test-logloss:0.02500
# [390]	test-logloss:0.02500
# [400]	test-logloss:0.02500
# [410]	test-logloss:0.02500
# [420]	test-logloss:0.02500
# [430]	test-logloss:0.02500
# [440]	test-logloss:0.02499
# [450]	test-logloss:0.02499
# [460]	test-logloss:0.02499
# [470]	test-logloss:0.02500
# [480]	test-logloss:0.02500
# [490]	test-logloss:0.02500
# [500]	test-logloss:0.02500
# 0.4463987492449277
# 0.4466521679871527
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet', './data_folds/fold_2/split/chunks/carts/chunk_1.parquet']
# ./data_folds/fold_1/split/chunks/carts/chunk_1.parquet
# (17837091, 171)
# Recall Train: 0.6972134098524274
# Recall Test: 0.5525763825770817
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.18999
# [20]	test-logloss:0.07919
# [30]	test-logloss:0.04314
# [40]	test-logloss:0.03107
# [50]	test-logloss:0.02712
# [60]	test-logloss:0.02586
# [70]	test-logloss:0.02543
# [80]	test-logloss:0.02524
# [90]	test-logloss:0.02515
# [100]	test-logloss:0.02510
# [110]	test-logloss:0.02506
# [120]	test-logloss:0.02504
# [130]	test-logloss:0.02502
# [140]	test-logloss:0.02501
# [150]	test-logloss:0.02499
# [160]	test-logloss:0.02499
# [170]	test-logloss:0.02498
# [180]	test-logloss:0.02497
# [190]	test-logloss:0.02497
# [200]	test-logloss:0.02496
# [210]	test-logloss:0.02496
# [220]	test-logloss:0.02495
# [230]	test-logloss:0.02495
# [240]	test-logloss:0.02495
# [250]	test-logloss:0.02495
# [260]	test-logloss:0.02495
# [270]	test-logloss:0.02494
# [280]	test-logloss:0.02494
# [290]	test-logloss:0.02494
# [300]	test-logloss:0.02494
# [310]	test-logloss:0.02494
# [320]	test-logloss:0.02494
# [330]	test-logloss:0.02494
# [340]	test-logloss:0.02494
# [350]	test-logloss:0.02493
# [360]	test-logloss:0.02493
# [370]	test-logloss:0.02493
# [380]	test-logloss:0.02493
# [390]	test-logloss:0.02493
# [400]	test-logloss:0.02493
# [410]	test-logloss:0.02493
# [420]	test-logloss:0.02493
# [424]	test-logloss:0.02493
# iseed: 1
# [0]	test-logloss:0.60046
# [10]	test-logloss:0.19007
# [20]	test-logloss:0.07921
# [30]	test-logloss:0.04313
# [40]	test-logloss:0.03106
# [50]	test-logloss:0.02714
# [60]	test-logloss:0.02588
# [70]	test-logloss:0.02543
# [80]	test-logloss:0.02525
# [90]	test-logloss:0.02516
# [100]	test-logloss:0.02511
# [110]	test-logloss:0.02507
# [120]	test-logloss:0.02505
# [130]	test-logloss:0.02503
# [140]	test-logloss:0.02501
# [150]	test-logloss:0.02500
# [160]	test-logloss:0.02499
# [170]	test-logloss:0.02498
# [180]	test-logloss:0.02498
# [190]	test-logloss:0.02497
# [200]	test-logloss:0.02497
# [210]	test-logloss:0.02496
# [220]	test-logloss:0.02496
# [230]	test-logloss:0.02496
# [240]	test-logloss:0.02496
# [250]	test-logloss:0.02495
# [260]	test-logloss:0.02495
# [270]	test-logloss:0.02495
# [280]	test-logloss:0.02495
# [290]	test-logloss:0.02495
# [300]	test-logloss:0.02494
# [310]	test-logloss:0.02494
# [320]	test-logloss:0.02494
# [330]	test-logloss:0.02494
# [340]	test-logloss:0.02494
# [350]	test-logloss:0.02494
# [360]	test-logloss:0.02493
# [370]	test-logloss:0.02493
# [380]	test-logloss:0.02494
# [390]	test-logloss:0.02493
# [400]	test-logloss:0.02493
# [410]	test-logloss:0.02494
# [420]	test-logloss:0.02493
# [430]	test-logloss:0.02493
# [440]	test-logloss:0.02493
# [450]	test-logloss:0.02494
# [460]	test-logloss:0.02494
# [470]	test-logloss:0.02494
# [472]	test-logloss:0.02493
# iseed: 2
# [0]	test-logloss:0.60043
# [10]	test-logloss:0.19003
# [20]	test-logloss:0.07918
# [30]	test-logloss:0.04310
# [40]	test-logloss:0.03107
# [50]	test-logloss:0.02713
# [60]	test-logloss:0.02585
# [70]	test-logloss:0.02541
# [80]	test-logloss:0.02523
# [90]	test-logloss:0.02514
# [100]	test-logloss:0.02509
# [110]	test-logloss:0.02506
# [120]	test-logloss:0.02504
# [130]	test-logloss:0.02502
# [140]	test-logloss:0.02501
# [150]	test-logloss:0.02500
# [160]	test-logloss:0.02499
# [170]	test-logloss:0.02498
# [180]	test-logloss:0.02497
# [190]	test-logloss:0.02497
# [200]	test-logloss:0.02496
# [210]	test-logloss:0.02496
# [220]	test-logloss:0.02495
# [230]	test-logloss:0.02495
# [240]	test-logloss:0.02494
# [250]	test-logloss:0.02494
# [260]	test-logloss:0.02494
# [270]	test-logloss:0.02494
# [280]	test-logloss:0.02494
# [290]	test-logloss:0.02494
# [300]	test-logloss:0.02494
# [310]	test-logloss:0.02493
# [320]	test-logloss:0.02493
# [330]	test-logloss:0.02494
# [340]	test-logloss:0.02493
# [350]	test-logloss:0.02493
# [360]	test-logloss:0.02493
# [370]	test-logloss:0.02493
# [380]	test-logloss:0.02493
# [390]	test-logloss:0.02493
# [400]	test-logloss:0.02493
# [410]	test-logloss:0.02493
# [420]	test-logloss:0.02493
# [430]	test-logloss:0.02493
# [440]	test-logloss:0.02493
# [450]	test-logloss:0.02493
# [457]	test-logloss:0.02493
# 0.4474900286402052
# 0.44686347844583096
# ['./data_folds/fold_2/split/chunks/carts/chunk_0.parquet', './data_folds/fold_2/split/chunks/carts/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_1.parquet']
# ./data_folds/fold_2/split/chunks/carts/chunk_0.parquet
# (17869746, 171)
# Recall Train: 0.6981324565858527
# Recall Test: 0.5451639799888827
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.19001
# [20]	test-logloss:0.07923
# [30]	test-logloss:0.04319
# [40]	test-logloss:0.03114
# [50]	test-logloss:0.02720
# [60]	test-logloss:0.02593
# [70]	test-logloss:0.02551
# [80]	test-logloss:0.02532
# [90]	test-logloss:0.02523
# [100]	test-logloss:0.02518
# [110]	test-logloss:0.02514
# [120]	test-logloss:0.02512
# [130]	test-logloss:0.02510
# [140]	test-logloss:0.02508
# [150]	test-logloss:0.02507
# [160]	test-logloss:0.02507
# [170]	test-logloss:0.02506
# [180]	test-logloss:0.02505
# [190]	test-logloss:0.02504
# [200]	test-logloss:0.02504
# [210]	test-logloss:0.02504
# [220]	test-logloss:0.02503
# [230]	test-logloss:0.02503
# [240]	test-logloss:0.02502
# [250]	test-logloss:0.02502
# [260]	test-logloss:0.02502
# [270]	test-logloss:0.02501
# [280]	test-logloss:0.02501
# [290]	test-logloss:0.02501
# [300]	test-logloss:0.02501
# [310]	test-logloss:0.02501
# [320]	test-logloss:0.02501
# [330]	test-logloss:0.02501
# [340]	test-logloss:0.02501
# [350]	test-logloss:0.02500
# [360]	test-logloss:0.02500
# [370]	test-logloss:0.02500
# [380]	test-logloss:0.02500
# [390]	test-logloss:0.02501
# [400]	test-logloss:0.02501
# [410]	test-logloss:0.02500
# [420]	test-logloss:0.02500
# [424]	test-logloss:0.02501
# iseed: 1
# [0]	test-logloss:0.60047
# [10]	test-logloss:0.19010
# [20]	test-logloss:0.07925
# [30]	test-logloss:0.04317
# [40]	test-logloss:0.03113
# [50]	test-logloss:0.02722
# [60]	test-logloss:0.02596
# [70]	test-logloss:0.02550
# [80]	test-logloss:0.02532
# [90]	test-logloss:0.02524
# [100]	test-logloss:0.02518
# [110]	test-logloss:0.02515
# [120]	test-logloss:0.02512
# [130]	test-logloss:0.02510
# [140]	test-logloss:0.02509
# [150]	test-logloss:0.02507
# [160]	test-logloss:0.02507
# [170]	test-logloss:0.02505
# [180]	test-logloss:0.02504
# [190]	test-logloss:0.02504
# [200]	test-logloss:0.02504
# [210]	test-logloss:0.02503
# [220]	test-logloss:0.02502
# [230]	test-logloss:0.02502
# [240]	test-logloss:0.02502
# [250]	test-logloss:0.02502
# [260]	test-logloss:0.02501
# [270]	test-logloss:0.02501
# [280]	test-logloss:0.02501
# [290]	test-logloss:0.02501
# [300]	test-logloss:0.02501
# [310]	test-logloss:0.02501
# [320]	test-logloss:0.02501
# [330]	test-logloss:0.02500
# [340]	test-logloss:0.02500
# [350]	test-logloss:0.02500
# [360]	test-logloss:0.02500
# [370]	test-logloss:0.02500
# [380]	test-logloss:0.02500
# [390]	test-logloss:0.02500
# [400]	test-logloss:0.02500
# [410]	test-logloss:0.02500
# [420]	test-logloss:0.02500
# [430]	test-logloss:0.02500
# [440]	test-logloss:0.02500
# [450]	test-logloss:0.02500
# [460]	test-logloss:0.02500
# [470]	test-logloss:0.02500
# [480]	test-logloss:0.02500
# [490]	test-logloss:0.02500
# [496]	test-logloss:0.02500
# iseed: 2
# [0]	test-logloss:0.60043
# [10]	test-logloss:0.19005
# [20]	test-logloss:0.07923
# [30]	test-logloss:0.04316
# [40]	test-logloss:0.03114
# [50]	test-logloss:0.02721
# [60]	test-logloss:0.02592
# [70]	test-logloss:0.02548
# [80]	test-logloss:0.02531
# [90]	test-logloss:0.02522
# [100]	test-logloss:0.02517
# [110]	test-logloss:0.02514
# [120]	test-logloss:0.02511
# [130]	test-logloss:0.02510
# [140]	test-logloss:0.02508
# [150]	test-logloss:0.02507
# [160]	test-logloss:0.02506
# [170]	test-logloss:0.02505
# [180]	test-logloss:0.02505
# [190]	test-logloss:0.02504
# [200]	test-logloss:0.02504
# [210]	test-logloss:0.02503
# [220]	test-logloss:0.02503
# [230]	test-logloss:0.02502
# [240]	test-logloss:0.02502
# [250]	test-logloss:0.02502
# [260]	test-logloss:0.02502
# [270]	test-logloss:0.02502
# [280]	test-logloss:0.02501
# [290]	test-logloss:0.02501
# [300]	test-logloss:0.02501
# [310]	test-logloss:0.02501
# [320]	test-logloss:0.02501
# [330]	test-logloss:0.02500
# [340]	test-logloss:0.02500
# [350]	test-logloss:0.02500
# [360]	test-logloss:0.02500
# [370]	test-logloss:0.02500
# [380]	test-logloss:0.02500
# [390]	test-logloss:0.02500
# [400]	test-logloss:0.02500
# [410]	test-logloss:0.02500
# [420]	test-logloss:0.02500
# [430]	test-logloss:0.02500
# [440]	test-logloss:0.02500
# [450]	test-logloss:0.02500
# [460]	test-logloss:0.02500
# [470]	test-logloss:0.02500
# [480]	test-logloss:0.02500
# [490]	test-logloss:0.02500
# [500]	test-logloss:0.02500
# [501]	test-logloss:0.02500
# 0.44081718250292723
# 0.44564045460169327
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet']
# ./data_folds/fold_2/split/chunks/carts/chunk_1.parquet
# (17909390, 171)
# Recall Train: 0.6982338570799237
# Recall Test: 0.547374519408016
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.19001
# [20]	test-logloss:0.07925
# [30]	test-logloss:0.04322
# [40]	test-logloss:0.03119
# [50]	test-logloss:0.02726
# [60]	test-logloss:0.02600
# [70]	test-logloss:0.02558
# [80]	test-logloss:0.02540
# [90]	test-logloss:0.02531
# [100]	test-logloss:0.02527
# [110]	test-logloss:0.02523
# [120]	test-logloss:0.02521
# [130]	test-logloss:0.02519
# [140]	test-logloss:0.02518
# [150]	test-logloss:0.02516
# [160]	test-logloss:0.02516
# [170]	test-logloss:0.02515
# [180]	test-logloss:0.02514
# [190]	test-logloss:0.02513
# [200]	test-logloss:0.02513
# [210]	test-logloss:0.02513
# [220]	test-logloss:0.02512
# [230]	test-logloss:0.02512
# [240]	test-logloss:0.02512
# [250]	test-logloss:0.02512
# [260]	test-logloss:0.02511
# [270]	test-logloss:0.02511
# [280]	test-logloss:0.02511
# [290]	test-logloss:0.02511
# [300]	test-logloss:0.02511
# [310]	test-logloss:0.02511
# [320]	test-logloss:0.02511
# [330]	test-logloss:0.02511
# [340]	test-logloss:0.02511
# [350]	test-logloss:0.02511
# [360]	test-logloss:0.02511
# [370]	test-logloss:0.02511
# [380]	test-logloss:0.02511
# [390]	test-logloss:0.02511
# [400]	test-logloss:0.02510
# [410]	test-logloss:0.02510
# [420]	test-logloss:0.02511
# [430]	test-logloss:0.02511
# [440]	test-logloss:0.02511
# [450]	test-logloss:0.02511
# [455]	test-logloss:0.02511
# iseed: 1
# [0]	test-logloss:0.60047
# [10]	test-logloss:0.19011
# [20]	test-logloss:0.07928
# [30]	test-logloss:0.04321
# [40]	test-logloss:0.03118
# [50]	test-logloss:0.02728
# [60]	test-logloss:0.02603
# [70]	test-logloss:0.02558
# [80]	test-logloss:0.02541
# [90]	test-logloss:0.02532
# [100]	test-logloss:0.02527
# [110]	test-logloss:0.02524
# [120]	test-logloss:0.02521
# [130]	test-logloss:0.02519
# [140]	test-logloss:0.02518
# [150]	test-logloss:0.02517
# [160]	test-logloss:0.02516
# [170]	test-logloss:0.02515
# [180]	test-logloss:0.02514
# [190]	test-logloss:0.02513
# [200]	test-logloss:0.02513
# [210]	test-logloss:0.02513
# [220]	test-logloss:0.02512
# [230]	test-logloss:0.02512
# [240]	test-logloss:0.02512
# [250]	test-logloss:0.02511
# [260]	test-logloss:0.02511
# [270]	test-logloss:0.02511
# [280]	test-logloss:0.02511
# [290]	test-logloss:0.02511
# [300]	test-logloss:0.02511
# [310]	test-logloss:0.02510
# [320]	test-logloss:0.02510
# [330]	test-logloss:0.02510
# [340]	test-logloss:0.02510
# [350]	test-logloss:0.02510
# [360]	test-logloss:0.02510
# [370]	test-logloss:0.02510
# [380]	test-logloss:0.02510
# [390]	test-logloss:0.02510
# [400]	test-logloss:0.02510
# [410]	test-logloss:0.02510
# [420]	test-logloss:0.02510
# [430]	test-logloss:0.02510
# [440]	test-logloss:0.02510
# [444]	test-logloss:0.02510
# iseed: 2
# [0]	test-logloss:0.60043
# [10]	test-logloss:0.19005
# [20]	test-logloss:0.07925
# [30]	test-logloss:0.04320
# [40]	test-logloss:0.03119
# [50]	test-logloss:0.02727
# [60]	test-logloss:0.02600
# [70]	test-logloss:0.02556
# [80]	test-logloss:0.02540
# [90]	test-logloss:0.02532
# [100]	test-logloss:0.02527
# [110]	test-logloss:0.02523
# [120]	test-logloss:0.02521
# [130]	test-logloss:0.02519
# [140]	test-logloss:0.02518
# [150]	test-logloss:0.02517
# [160]	test-logloss:0.02516
# [170]	test-logloss:0.02515
# [180]	test-logloss:0.02514
# [190]	test-logloss:0.02514
# [200]	test-logloss:0.02513
# [210]	test-logloss:0.02513
# [220]	test-logloss:0.02512
# [230]	test-logloss:0.02512
# [240]	test-logloss:0.02512
# [250]	test-logloss:0.02512
# [260]	test-logloss:0.02512
# [270]	test-logloss:0.02511
# [280]	test-logloss:0.02511
# [290]	test-logloss:0.02511
# [300]	test-logloss:0.02511
# [310]	test-logloss:0.02510
# [320]	test-logloss:0.02510
# [330]	test-logloss:0.02510
# [340]	test-logloss:0.02510
# [350]	test-logloss:0.02511
# [360]	test-logloss:0.02510
# [368]	test-logloss:0.02511
# 0.4434945419860812
# 0.44528260760709165
# ['./data_folds/fold_3/split/chunks/carts/chunk_0.parquet', './data_folds/fold_3/split/chunks/carts/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet']
# ./data_folds/fold_3/split/chunks/carts/chunk_0.parquet
# (17909390, 171)
# Recall Train: 0.6982338570799237
# Recall Test: 0.5496160712738114
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.19002
# [20]	test-logloss:0.07926
# [30]	test-logloss:0.04324
# [40]	test-logloss:0.03124
# [50]	test-logloss:0.02733
# [60]	test-logloss:0.02609
# [70]	test-logloss:0.02568
# [80]	test-logloss:0.02550
# [90]	test-logloss:0.02541
# [100]	test-logloss:0.02537
# [110]	test-logloss:0.02533
# [120]	test-logloss:0.02530
# [130]	test-logloss:0.02529
# [140]	test-logloss:0.02527
# [150]	test-logloss:0.02526
# [160]	test-logloss:0.02525
# [170]	test-logloss:0.02524
# [180]	test-logloss:0.02524
# [190]	test-logloss:0.02523
# [200]	test-logloss:0.02522
# [210]	test-logloss:0.02522
# [220]	test-logloss:0.02522
# [230]	test-logloss:0.02521
# [240]	test-logloss:0.02521
# [250]	test-logloss:0.02521
# [260]	test-logloss:0.02520
# [270]	test-logloss:0.02520
# [280]	test-logloss:0.02520
# [290]	test-logloss:0.02520
# [300]	test-logloss:0.02520
# [310]	test-logloss:0.02520
# [320]	test-logloss:0.02520
# [330]	test-logloss:0.02520
# [340]	test-logloss:0.02520
# [350]	test-logloss:0.02520
# [360]	test-logloss:0.02520
# [370]	test-logloss:0.02520
# [380]	test-logloss:0.02520
# [390]	test-logloss:0.02520
# [400]	test-logloss:0.02519
# [410]	test-logloss:0.02519
# [420]	test-logloss:0.02519
# [430]	test-logloss:0.02519
# [440]	test-logloss:0.02519
# [450]	test-logloss:0.02519
# [456]	test-logloss:0.02520
# iseed: 1
# [0]	test-logloss:0.60047
# [10]	test-logloss:0.19011
# [20]	test-logloss:0.07929
# [30]	test-logloss:0.04324
# [40]	test-logloss:0.03124
# [50]	test-logloss:0.02736
# [60]	test-logloss:0.02613
# [70]	test-logloss:0.02568
# [80]	test-logloss:0.02551
# [90]	test-logloss:0.02542
# [100]	test-logloss:0.02537
# [110]	test-logloss:0.02534
# [120]	test-logloss:0.02531
# [130]	test-logloss:0.02529
# [140]	test-logloss:0.02528
# [150]	test-logloss:0.02527
# [160]	test-logloss:0.02526
# [170]	test-logloss:0.02525
# [180]	test-logloss:0.02524
# [190]	test-logloss:0.02524
# [200]	test-logloss:0.02523
# [210]	test-logloss:0.02523
# [220]	test-logloss:0.02523
# [230]	test-logloss:0.02522
# [240]	test-logloss:0.02522
# [250]	test-logloss:0.02522
# [260]	test-logloss:0.02522
# [270]	test-logloss:0.02522
# [280]	test-logloss:0.02521
# [290]	test-logloss:0.02521
# [300]	test-logloss:0.02521
# [310]	test-logloss:0.02521
# [320]	test-logloss:0.02521
# [330]	test-logloss:0.02521
# [340]	test-logloss:0.02521
# [350]	test-logloss:0.02520
# [360]	test-logloss:0.02520
# [370]	test-logloss:0.02520
# [380]	test-logloss:0.02520
# [390]	test-logloss:0.02520
# [400]	test-logloss:0.02520
# [410]	test-logloss:0.02520
# iseed: 2
# [0]	test-logloss:0.60044
# [10]	test-logloss:0.19006
# [20]	test-logloss:0.07926
# [30]	test-logloss:0.04322
# [40]	test-logloss:0.03125
# [50]	test-logloss:0.02734
# [60]	test-logloss:0.02609
# [70]	test-logloss:0.02566
# [80]	test-logloss:0.02550
# [90]	test-logloss:0.02542
# [100]	test-logloss:0.02537
# [110]	test-logloss:0.02533
# [120]	test-logloss:0.02530
# [130]	test-logloss:0.02528
# [140]	test-logloss:0.02527
# [150]	test-logloss:0.02526
# [160]	test-logloss:0.02525
# [170]	test-logloss:0.02524
# [180]	test-logloss:0.02524
# [190]	test-logloss:0.02523
# [200]	test-logloss:0.02523
# [210]	test-logloss:0.02522
# [220]	test-logloss:0.02521
# [230]	test-logloss:0.02522
# [240]	test-logloss:0.02521
# [250]	test-logloss:0.02521
# [260]	test-logloss:0.02521
# [270]	test-logloss:0.02520
# [280]	test-logloss:0.02520
# [290]	test-logloss:0.02520
# [300]	test-logloss:0.02520
# [310]	test-logloss:0.02520
# [320]	test-logloss:0.02520
# [330]	test-logloss:0.02520
# [340]	test-logloss:0.02520
# [350]	test-logloss:0.02520
# [360]	test-logloss:0.02520
# [370]	test-logloss:0.02520
# [380]	test-logloss:0.02520
# [390]	test-logloss:0.02520
# [400]	test-logloss:0.02520
# [410]	test-logloss:0.02520
# [420]	test-logloss:0.02520
# [430]	test-logloss:0.02520
# [440]	test-logloss:0.02520
# [446]	test-logloss:0.02520
# 0.44486992569692074
# 0.44522334446608214
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet']
# ./data_folds/fold_3/split/chunks/carts/chunk_1.parquet
# (17909390, 171)
# Recall Train: 0.6982338570799237
# Recall Test: 0.545736568457539
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.19001
# [20]	test-logloss:0.07925
# [30]	test-logloss:0.04322
# [40]	test-logloss:0.03118
# [50]	test-logloss:0.02725
# [60]	test-logloss:0.02599
# [70]	test-logloss:0.02556
# [80]	test-logloss:0.02538
# [90]	test-logloss:0.02528
# [100]	test-logloss:0.02523
# [110]	test-logloss:0.02519
# [120]	test-logloss:0.02517
# [130]	test-logloss:0.02515
# [140]	test-logloss:0.02513
# [150]	test-logloss:0.02511
# [160]	test-logloss:0.02510
# [170]	test-logloss:0.02510
# [180]	test-logloss:0.02509
# [190]	test-logloss:0.02508
# [200]	test-logloss:0.02507
# [210]	test-logloss:0.02507
# [220]	test-logloss:0.02506
# [230]	test-logloss:0.02506
# [240]	test-logloss:0.02505
# [250]	test-logloss:0.02505
# [260]	test-logloss:0.02505
# [270]	test-logloss:0.02504
# [280]	test-logloss:0.02504
# [290]	test-logloss:0.02504
# [300]	test-logloss:0.02504
# [310]	test-logloss:0.02504
# [320]	test-logloss:0.02504
# [330]	test-logloss:0.02503
# [340]	test-logloss:0.02503
# [350]	test-logloss:0.02503
# [360]	test-logloss:0.02503
# [370]	test-logloss:0.02503
# [380]	test-logloss:0.02503
# [390]	test-logloss:0.02503
# [391]	test-logloss:0.02503
# iseed: 1
# [0]	test-logloss:0.60047
# [10]	test-logloss:0.19011
# [20]	test-logloss:0.07928
# [30]	test-logloss:0.04322
# [40]	test-logloss:0.03118
# [50]	test-logloss:0.02727
# [60]	test-logloss:0.02602
# [70]	test-logloss:0.02557
# [80]	test-logloss:0.02539
# [90]	test-logloss:0.02530
# [100]	test-logloss:0.02524
# [110]	test-logloss:0.02521
# [120]	test-logloss:0.02518
# [130]	test-logloss:0.02516
# [140]	test-logloss:0.02514
# [150]	test-logloss:0.02513
# [160]	test-logloss:0.02512
# [170]	test-logloss:0.02511
# [180]	test-logloss:0.02510
# [190]	test-logloss:0.02509
# [200]	test-logloss:0.02509
# [210]	test-logloss:0.02508
# [220]	test-logloss:0.02507
# [230]	test-logloss:0.02507
# [240]	test-logloss:0.02507
# [250]	test-logloss:0.02507
# [260]	test-logloss:0.02506
# [270]	test-logloss:0.02506
# [280]	test-logloss:0.02506
# [290]	test-logloss:0.02506
# [300]	test-logloss:0.02506
# [310]	test-logloss:0.02506
# [320]	test-logloss:0.02506
# [330]	test-logloss:0.02506
# [340]	test-logloss:0.02505
# [350]	test-logloss:0.02505
# [360]	test-logloss:0.02505
# [370]	test-logloss:0.02505
# [380]	test-logloss:0.02505
# [390]	test-logloss:0.02505
# [400]	test-logloss:0.02505
# [410]	test-logloss:0.02505
# [415]	test-logloss:0.02505
# iseed: 2
# [0]	test-logloss:0.60043
# [10]	test-logloss:0.19006
# [20]	test-logloss:0.07925
# [30]	test-logloss:0.04320
# [40]	test-logloss:0.03119
# [50]	test-logloss:0.02727
# [60]	test-logloss:0.02599
# [70]	test-logloss:0.02555
# [80]	test-logloss:0.02539
# [90]	test-logloss:0.02530
# [100]	test-logloss:0.02525
# [110]	test-logloss:0.02521
# [120]	test-logloss:0.02518
# [130]	test-logloss:0.02516
# [140]	test-logloss:0.02514
# [150]	test-logloss:0.02513
# [160]	test-logloss:0.02512
# [170]	test-logloss:0.02511
# [180]	test-logloss:0.02510
# [190]	test-logloss:0.02509
# [200]	test-logloss:0.02509
# [210]	test-logloss:0.02508
# [220]	test-logloss:0.02508
# [230]	test-logloss:0.02508
# [240]	test-logloss:0.02508
# [250]	test-logloss:0.02508
# [260]	test-logloss:0.02507
# [270]	test-logloss:0.02507
# [280]	test-logloss:0.02507
# [290]	test-logloss:0.02507
# [300]	test-logloss:0.02506
# [310]	test-logloss:0.02506
# [320]	test-logloss:0.02506
# [330]	test-logloss:0.02506
# [340]	test-logloss:0.02506
# [350]	test-logloss:0.02506
# [360]	test-logloss:0.02506
# [370]	test-logloss:0.02506
# [380]	test-logloss:0.02506
# [388]	test-logloss:0.02506
# 0.4428224269655064
# 0.4449206065776508
# ['./data_folds/fold_4/split/chunks/carts/chunk_0.parquet', './data_folds/fold_4/split/chunks/carts/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet']
# ./data_folds/fold_4/split/chunks/carts/chunk_0.parquet
# (17909390, 171)
# Recall Train: 0.6982338570799237
# Recall Test: 0.5512851811809019
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.19000
# [20]	test-logloss:0.07924
# [30]	test-logloss:0.04320
# [40]	test-logloss:0.03117
# [50]	test-logloss:0.02724
# [60]	test-logloss:0.02599
# [70]	test-logloss:0.02557
# [80]	test-logloss:0.02538
# [90]	test-logloss:0.02530
# [100]	test-logloss:0.02525
# [110]	test-logloss:0.02521
# [120]	test-logloss:0.02519
# [130]	test-logloss:0.02517
# [140]	test-logloss:0.02516
# [150]	test-logloss:0.02515
# [160]	test-logloss:0.02514
# [170]	test-logloss:0.02513
# [180]	test-logloss:0.02513
# [190]	test-logloss:0.02512
# [200]	test-logloss:0.02511
# [210]	test-logloss:0.02511
# [220]	test-logloss:0.02511
# [230]	test-logloss:0.02510
# [240]	test-logloss:0.02510
# [250]	test-logloss:0.02510
# [260]	test-logloss:0.02509
# [270]	test-logloss:0.02509
# [280]	test-logloss:0.02509
# [290]	test-logloss:0.02509
# [300]	test-logloss:0.02509
# [310]	test-logloss:0.02509
# [320]	test-logloss:0.02509
# [330]	test-logloss:0.02509
# [340]	test-logloss:0.02509
# [350]	test-logloss:0.02509
# [360]	test-logloss:0.02509
# [369]	test-logloss:0.02509
# iseed: 1
# [0]	test-logloss:0.60047
# [10]	test-logloss:0.19010
# [20]	test-logloss:0.07926
# [30]	test-logloss:0.04319
# [40]	test-logloss:0.03116
# [50]	test-logloss:0.02726
# [60]	test-logloss:0.02601
# [70]	test-logloss:0.02556
# [80]	test-logloss:0.02539
# [90]	test-logloss:0.02531
# [100]	test-logloss:0.02525
# [110]	test-logloss:0.02522
# [120]	test-logloss:0.02520
# [130]	test-logloss:0.02518
# [140]	test-logloss:0.02516
# [150]	test-logloss:0.02515
# [160]	test-logloss:0.02532
# [170]	test-logloss:0.02531
# [180]	test-logloss:0.02530
# [190]	test-logloss:0.02530
# [200]	test-logloss:0.02529
# [210]	test-logloss:0.02529
# [220]	test-logloss:0.02528
# [230]	test-logloss:0.02528
# [240]	test-logloss:0.02528
# [250]	test-logloss:0.02527
# [260]	test-logloss:0.02527
# [270]	test-logloss:0.02527
# [280]	test-logloss:0.02527
# [290]	test-logloss:0.02526
# [300]	test-logloss:0.02527
# [310]	test-logloss:0.02526
# [320]	test-logloss:0.02526
# [330]	test-logloss:0.02526
# [340]	test-logloss:0.02526
# [350]	test-logloss:0.02526
# [360]	test-logloss:0.02526
# [370]	test-logloss:0.02526
# [380]	test-logloss:0.02526
# [390]	test-logloss:0.02526
# [400]	test-logloss:0.02526
# [410]	test-logloss:0.02526
# [420]	test-logloss:0.02525
# [430]	test-logloss:0.02526
# [440]	test-logloss:0.02526
# [450]	test-logloss:0.02526
# [460]	test-logloss:0.02526
# [467]	test-logloss:0.02526
# iseed: 1
# [0]	test-logloss:0.60047
# [10]	test-logloss:0.19017
# [20]	test-logloss:0.07938
# [30]	test-logloss:0.04335
# [40]	test-logloss:0.03133
# [50]	test-logloss:0.02745
# [60]	test-logloss:0.02621
# [70]	test-logloss:0.02575
# [80]	test-logloss:0.02558
# [90]	test-logloss:0.02549
# [100]	test-logloss:0.02543
# [110]	test-logloss:0.02540
# [120]	test-logloss:0.02537
# [130]	test-logloss:0.02535
# [140]	test-logloss:0.02534
# [150]	test-logloss:0.02532
# [160]	test-logloss:0.02531
# [170]	test-logloss:0.02531
# [180]	test-logloss:0.02530
# [190]	test-logloss:0.02529
# [200]	test-logloss:0.02529
# [210]	test-logloss:0.02528
# [220]	test-logloss:0.02528
# [230]	test-logloss:0.02528
# [240]	test-logloss:0.02527
# [250]	test-logloss:0.02527
# [260]	test-logloss:0.02527
# [270]	test-logloss:0.02527
# [280]	test-logloss:0.02527
# [290]	test-logloss:0.02526
# [300]	test-logloss:0.02526
# [310]	test-logloss:0.02526
# [320]	test-logloss:0.02526
# [330]	test-logloss:0.02526
# [340]	test-logloss:0.02525
# [350]	test-logloss:0.02525
# [360]	test-logloss:0.02525
# [370]	test-logloss:0.02525
# [380]	test-logloss:0.02525
# [390]	test-logloss:0.02525
# [400]	test-logloss:0.02525
# [410]	test-logloss:0.02526
# iseed: 2
# [0]	test-logloss:0.60045
# [10]	test-logloss:0.19012
# [20]	test-logloss:0.07936
# [30]	test-logloss:0.04334
# [40]	test-logloss:0.03135
# [50]	test-logloss:0.02744
# [60]	test-logloss:0.02617
# [70]	test-logloss:0.02573
# [80]	test-logloss:0.02557
# [90]	test-logloss:0.02548
# [100]	test-logloss:0.02543
# [110]	test-logloss:0.02539
# [120]	test-logloss:0.02537
# [130]	test-logloss:0.02535
# [140]	test-logloss:0.02534
# [150]	test-logloss:0.02533
# [160]	test-logloss:0.02532
# [170]	test-logloss:0.02531
# [180]	test-logloss:0.02530
# [190]	test-logloss:0.02529
# [200]	test-logloss:0.02529
# [210]	test-logloss:0.02528
# [220]	test-logloss:0.02528
# [230]	test-logloss:0.02528
# [240]	test-logloss:0.02527
# [250]	test-logloss:0.02527
# [260]	test-logloss:0.02527
# [270]	test-logloss:0.02527
# [280]	test-logloss:0.02526
# [290]	test-logloss:0.02526
# [300]	test-logloss:0.02526
# [310]	test-logloss:0.02526
# [320]	test-logloss:0.02526
# [330]	test-logloss:0.02526
# [340]	test-logloss:0.02526
# [350]	test-logloss:0.02526
# [360]	test-logloss:0.02526
# [370]	test-logloss:0.02526
# [380]	test-logloss:0.02526
# [390]	test-logloss:0.02526
# [400]	test-logloss:0.02526
# [407]	test-logloss:0.02526
# 0.44643077737580517
# 0.4453133129108093
# CPU times: user 1h 46min 13s, sys: 17min 57s, total: 2h 4min 11s
# Wall time: 1h 8min 25s

# %%
if not bl_sub:
    # Print average number of trees for submission
    import numpy as np
    np.mean(model_bests), np.std(model_bests), np.min(model_bests), np.max(model_bests)
# Out:
# (377.26666666666665, 40.656228168497, 313, 451)

# %%
# %%time

if bl_sub:
    # Submission
    # As the dataset is too large, only 5-folds can be loaded at once
    # There will be 2x models trained (10 folds // 5), each model has 10x bags and predict 5x submission datasets
    hist_recall = []
    total_no_hit = 0
    total_no_gt = 0
    for igfold in range(1):
        files = ['x', 'y']
        print(files)
        for ifile, file in enumerate(files):
            if bl_sub:
                if ty == 'clicks':
                    test_files = []
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
                elif ty == 'carts':
                    test_files = []
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
                elif ty == 'orders':
                    test_files = []
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
                else:
                    assert 0!=0

                train_files = sorted([
                    y for x in [
                        sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
                        for igfold2 in range(0,5)
                    ] for y in x
                ])

                step=5
                train_files_list = []
                for i in range(0, len(train_files), step):
                    x = i
                    train_files_list.append(train_files[x:x+step])
                train_files = train_files_list[ifile]
                print(train_files)

                if ty == 'clicks':
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
                elif ty == 'carts':
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
                elif ty == 'orders':
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
            else:
                if ty == 'clicks':
                    test_files = files[ifile]
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
                elif ty == 'carts':
                    test_files = files[ifile]
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
                elif ty == 'orders':
                    test_files = files[ifile]
                    train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
                else:
                    assert 0!=0

                train_files = [
                    y for x in [
                        sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
                        for igfold2 in range(0,5)
                    ] for y in x if y not in test_files]

                if ty == 'clicks':
                    df_test = pd.read_parquet(test_files)
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])
                elif ty == 'carts':
                    df_test = cudf.read_parquet(test_files)
                    df_train = cudf.concat([
                        cudf.read_parquet(x) for x in train_files
                    ])
                elif ty == 'orders':
                    df_test = pd.read_parquet(test_files)
                    df_train = pd.concat([
                        pd.read_parquet(x) for x in train_files
                    ])

            print(train_files)
            print(test_files)

            if bl_pos:
                df_train = df_train[df_train['session'].isin(
                    df_train[df_train['target']==1]['session'].drop_duplicates().values
                )]

            train_cols = [x for x in df_train.columns if x not in [
                'session', 'cand', 'target', 'target_clicks', 'target_carts', 'target_orders'
            ] + ingore_cols]

            print('Recall Train: ' + str(df_train[df_train['target']==1].shape[0]/labels[
            (labels['session'].isin(df_train['session'].drop_duplicates()))&(labels['type']==ty)
        ].shape[0]))
            if not bl_sub:
                print('Recall Test: ' + str(df_test[df_test['target']==1].shape[0]/labels[
                (labels['session'].isin(df_test['session'].drop_duplicates()))&(labels['type']==ty)
            ].shape[0]))

            dtrain = xgb.DMatrix(data=df_train[train_cols].values,label=df_train['target'].values)
            if not bl_sub:
                dtest =  xgb.DMatrix(data=df_test[train_cols].values, label=df_test['target'].values)
                df_test['score'] = 0.0

            del df_train
            gc.collect()

            models = []
            for iseed in range(no_seeds):
                print('iseed: ' + str(iseed))
                xgb_parms['seed'] = iseed
                if bl_sub:
                    model = xgb.train(
                        xgb_parms, 
                        dtrain=dtrain,
                        evals=[(dtrain,'train')],
                        num_boost_round=no_trees,
                        verbose_eval=10
                    )
                else:
                    model = xgb.train(
                        xgb_parms, 
                        dtrain=dtrain,
                        evals=[(dtest,'test')],
                        num_boost_round=no_trees,
                        verbose_eval=10,
                        early_stopping_rounds=50
                    )
                    df_test['score'] += model.predict(dtest)
                models.append(model)
            del dtrain

            if bl_sub:
                for igfold2 in range(5):
                    for isubfile, sub_file in enumerate(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/sub/*.parquet')):
                        print('isubfile: ' + str(isubfile))
                        df_sub = cudf.read_parquet(sub_file).fillna(-999)
                        df_sub['score'] = 0.0
                        dsub = xgb.DMatrix(data=df_sub[train_cols].to_pandas().values)
                        for iseed in range(no_seeds):
                            df_sub['score_' + str(iseed)] = models[iseed].predict(dsub)
                        iseed = 0
                        os.system('mkdir -p ../00_submissions/' + outputfolder)
                        df_sub[['session', 'cand'] + ['score_' + str(ij) for ij in range(no_seeds)]].to_parquet(
                            '../00_submissions/' + outputfolder + '/sub_' + str(igfold2) + '_' + ty + '_' + str(ifile) + '_' + str(isubfile) + '.parquet'
                        )
                        del df_sub
                        gc.collect()
                del model
                gc.collect()

            gc.collect()
# Out:
# ['x', 'y']
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet']
# ['./data_folds/fold_0/split/chunks/carts/chunk_0.parquet', './data_folds/fold_0/split/chunks/carts/chunk_1.parquet', './data_folds/fold_1/split/chunks/carts/chunk_0.parquet', './data_folds/fold_1/split/chunks/carts/chunk_1.parquet', './data_folds/fold_2/split/chunks/carts/chunk_0.parquet']
# []
# Recall Train: 0.6982338570799237
# iseed: 0
# [0]	train-logloss:0.60062
# [10]	train-logloss:0.19175
# [20]	train-logloss:0.08197
# [30]	train-logloss:0.04663
# [40]	train-logloss:0.03503
# [50]	train-logloss:0.03134
# [60]	train-logloss:0.03015
# [70]	train-logloss:0.02970
# [80]	train-logloss:0.02944
# [90]	train-logloss:0.02926
# [100]	train-logloss:0.02913
# [110]	train-logloss:0.02900
# [120]	train-logloss:0.02889
# [130]	train-logloss:0.02880
# [140]	train-logloss:0.02871
# [150]	train-logloss:0.02863
# [160]	train-logloss:0.02856
# [170]	train-logloss:0.02847
# [180]	train-logloss:0.02840
# [190]	train-logloss:0.02832
# [200]	train-logloss:0.02825
# [210]	train-logloss:0.02818
# [220]	train-logloss:0.02810
# [230]	train-logloss:0.02803
# [240]	train-logloss:0.02796
# [250]	train-logloss:0.02790
# [260]	train-logloss:0.02784
# [270]	train-logloss:0.02778
# [280]	train-logloss:0.02772
# [290]	train-logloss:0.02766
# [300]	train-logloss:0.02760
# [310]	train-logloss:0.02754
# [320]	train-logloss:0.02748
# [330]	train-logloss:0.02743
# [340]	train-logloss:0.02736
