# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# !nvidia-smi
# Out:
# Mon Jan 30 21:47:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.119.04   Driver Version: 450.119.04   CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:06:00.0 Off |                    0 |
# | N/A   33C    P0    43W / 163W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla V100-SXM2...  On   | 00000000:07:00.0 Off |                    0 |
# | N/A   35C    P0    47W / 163W |   4654MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  Tesla V100-SXM2...  On   | 00000000:0A:00.0 Off |                    0 |
# | N/A   35C    P0    46W / 163W |   4542MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  Tesla V100-SXM2...  On   | 00000000:0B:00.0 Off |                    0 |
# | N/A   33C    P0    47W / 163W |   2688MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  Tesla V100-SXM2...  On   | 00000000:85:00.0 Off |                    0 |
# | N/A   34C    P0    46W / 163W |   4286MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  Tesla V100-SXM2...  On   | 00000000:86:00.0 Off |                    0 |
# | N/A   34C    P0    46W / 163W |   4532MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  Tesla V100-SXM2...  On   | 00000000:89:00.0 Off |                    0 |
# | N/A   37C    P0    47W / 163W |   6646MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   7  Tesla V100-SXM2...  On   | 00000000:8A:00.0 Off |                    0 |
# | N/A   34C    P0    43W / 163W |      0MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
def get_df(ty='clicks'):
    if ty=='clicks':
        for i in range(no_chunks):
            for j in range(5):
                files = glob.glob('../00_submissions/' + outputfolder + '/sub_' + str(i) + '_' + ty + '_' + str(j) + '*.parquet')
                print(files)
                if i == 0 and j==0:
                    df = cudf.concat([cudf.read_parquet(x) for x in files])
                    df['score'] = df[['score_' + str(iseed) for iseed in range(no_seeds)]].sum(axis=1)
                    df.drop(['score_' + str(iseed) for iseed in range(no_seeds)], axis=1, inplace=True)
                    print(df.isna().sum().sum())
                else:
                    df_tmp = cudf.concat([cudf.read_parquet(x) for x in files])
                    df_tmp['score'] = df_tmp[['score_' + str(iseed) for iseed in range(no_seeds)]].sum(axis=1)
                    df_tmp.drop(['score_' + str(iseed) for iseed in range(no_seeds)], axis=1, inplace=True)
                    df_tmp = df_tmp.rename(columns={'score':'score_2'})
                    print(df_tmp.isna().sum().sum())
                    df = df.merge(
                        df_tmp,
                        how='left',
                        on=['session', 'cand']
                    )
                    print(df.isna().sum())
                    df['score'] = df['score'].fillna(0) + df['score_2'].fillna(0)
                    df.drop(['score_2'], inplace=True, axis=1)
                    del df_tmp
                    gc.collect()
                print(df.shape)
    elif ty=='carts':
        for i in range(no_chunks):
            for j in range(2):
                files = glob.glob('../00_submissions/' + outputfolder + '/sub_' + str(i) + '_' + ty + '_' + str(j) + '*.parquet')
                print(files)
                if i == 0 and j==0:
                    df = cudf.concat([cudf.read_parquet(x) for x in files])
                    df['score'] = df[['score_' + str(iseed) for iseed in range(no_seeds)]].sum(axis=1)
                    df.drop(['score_' + str(iseed) for iseed in range(no_seeds)], axis=1, inplace=True)
                    print(df.isna().sum().sum())
                else:
                    df_tmp = cudf.concat([cudf.read_parquet(x) for x in files])
                    df_tmp['score'] = df_tmp[['score_' + str(iseed) for iseed in range(no_seeds)]].sum(axis=1)
                    df_tmp.drop(['score_' + str(iseed) for iseed in range(no_seeds)], axis=1, inplace=True)
                    df_tmp = df_tmp.rename(columns={'score':'score_2'})
                    print(df_tmp.isna().sum().sum())
                    df = df.merge(
                        df_tmp,
                        how='left',
                        on=['session', 'cand']
                    )
                    print(df.isna().sum())
                    df['score'] = df['score'].fillna(0) + df['score_2'].fillna(0)
                    df.drop(['score_2'], inplace=True, axis=1)
                    del df_tmp
                    gc.collect()
                print(df.shape)
    else:
        for i in range(no_chunks):
            files = glob.glob('../00_submissions/' + outputfolder + '/sub_' + str(i) + '_' + ty + '_' + str(0) + '*.parquet')
            if i == 0:
                df = cudf.concat([cudf.read_parquet(x) for x in files])
                print(df.head())
                #df['score'] = df[['score_' + str(iseed) for iseed in range(no_seeds)]].sum(axis=1)
                #df.drop(['score_' + str(iseed) for iseed in range(no_seeds)], axis=1, inplace=True)
                print(df.isna().sum().sum())
            else:
                df_tmp = cudf.concat([cudf.read_parquet(x) for x in files])
                print(df_tmp.head())
                #df_tmp['score'] = df_tmp[['score_' + str(iseed) for iseed in range(no_seeds)]].sum(axis=1)
                #df_tmp.drop(['score_' + str(iseed) for iseed in range(no_seeds)], axis=1, inplace=True)
                df_tmp = df_tmp.rename(columns={'score':'score_2'})
                print(df_tmp.isna().sum().sum())
                df = df.merge(
                    df_tmp,
                    how='left',
                    on=['session', 'cand']
                )
                print(df.isna().sum())
                df['score'] = df['score'].fillna(0) + df['score_2'].fillna(0)
                df.drop(['score_2'], inplace=True, axis=1)
                del df_tmp
                gc.collect()
            print(df.shape)
    return(df)

def prep_xgb(df, df_baseline, ty):
    df = df.sort_values(['session', 'score'], ascending=[True, False])
    df['dummy'] = 1
    df['rank'] = df.groupby(['session']).dummy.cumsum()
    df.drop(['dummy'], axis=1, inplace=True)
    df = df[df['rank']<21]
    
    df = df[['session', 'cand']].groupby(['session']).agg(list).reset_index()
    df = df.to_pandas()
    print(df.shape, df_baseline.shape)
    
    df = df.merge(
        df_baseline,
        how='left',
        on=['session']
    )
    
    list1 = df['cand'].tolist()
    list2 = df['labels'].tolist()
    
    out = []
    for i, (l1, l2) in enumerate(zip(list1, list2)):
        l1 = l1.tolist()
        if len(l1)==20:
            out.append(l1[0:20])
        else:
            l1 = l1 + [x for x in l2 if x not in l1]
            l1 = l1[0:20]
            out.append(l1)
    
    df_final = df[['session']]
    df_final['labels'] = out
    df_final['labels'] = df_final['labels'].apply(lambda x: " ".join(map(str,x)))
    df_final['session_type'] = df_final['session'].astype('str') + '_' + ty
    return(df_final)

# %%
import cudf
import glob
import gc

import pandas as pd

no_chunks = 5
no_seeds = 10
outputfolder = '24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5'

# %%
# Submission file from https://www.kaggle.com/code/cdeotte/candidate-rerank-model-lb-0-575 
# to fill up sessions with less than 20 Candidates
df_baseline = pd.read_csv('../00_submissions/' + '01_baseline' + '/submission.csv')
df_baseline['session'] = df_baseline.session_type.apply(lambda x: int(x.split('_')[0]))
df_baseline['type'] = df_baseline.session_type.apply(lambda x: x.split('_')[1])
df_baseline['session'].drop_duplicates().shape

# %%
# %%time

df_baseline.labels = df_baseline.labels.apply(lambda x: [int(i) for i in x.split(' ')[:20]])
# Out:
# CPU times: user 51.5 s, sys: 2.87 s, total: 54.3 s
# Wall time: 54.3 s

# %%
# %%time
ty='carts'
df = get_df(ty=ty)
df['score_norm'] = df['score']/(no_chunks*no_seeds)
df.to_parquet('../00_submissions/' + outputfolder + '/000_sub_carts.parquet')
df_carts_final = prep_xgb(df, df_baseline[df_baseline['type']==ty], ty=ty)
del df
gc.collect()
# Out:
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_6.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_14.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_0_24.parquet']
# 0
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_14.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_24.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_6.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_0_carts_1_15.parquet']
# 0
# session    0
# cand       0
# score      0
# score_2    0
# dtype: int64
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_14.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_24.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_0_6.parquet']
# 0
# session          0
# cand             0
# score            0
# score_2    6796677
# dtype: int64
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_24.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_14.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_1_carts_1_6.parquet']
# 0
# session          0
# cand             0
# score            0
# score_2    6796677
# dtype: int64
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_14.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_6.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_24.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_0_8.parquet']
# 0
# session          0
# cand             0
# score            0
# score_2    6894091
# dtype: int64
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_6.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_24.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_2_carts_1_14.parquet']
# 0
# session          0
# cand             0
# score            0
# score_2    6894091
# dtype: int64
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_24.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_6.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_0_14.parquet']
# 0
# session          0
# cand             0
# score            0
# score_2    6925035
# dtype: int64
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_6.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_14.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_3_carts_1_24.parquet']
# 0
# session          0
# cand             0
# score            0
# score_2    6925035
# dtype: int64
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_24.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_2.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_6.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_0_14.parquet']
# 0
# session          0
# cand             0
# score            0
# score_2    6873580
# dtype: int64
# (227147263, 3)
# ['../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_24.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_23.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_22.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_11.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_5.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_15.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_13.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_16.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_19.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_8.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_18.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_0.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_7.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_20.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_3.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_9.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_4.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_1.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_17.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_21.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_14.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_10.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_12.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_6.parquet', '../00_submissions/24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v5/sub_4_carts_1_2.parquet']
# 0
# session          0
# cand             0
# score            0
# score_2    6873580
# dtype: int64
# (227147263, 3)
# (1671803, 2) (1671803, 4)
# /tmp/ipykernel_75324/1922920730.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['labels'] = out
# /tmp/ipykernel_75324/1922920730.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['labels'] = df_final['labels'].apply(lambda x: " ".join(map(str,x)))
# /tmp/ipykernel_75324/1922920730.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['session_type'] = df_final['session'].astype('str') + '_' + ty
# CPU times: user 1min 34s, sys: 1min 45s, total: 3min 20s
# Wall time: 3min 35s
# 0

# %%
df_carts_final[['session_type', 'labels']].to_csv('../00_submissions/' + outputfolder + '/submission_carts_v2.csv', index=False)
