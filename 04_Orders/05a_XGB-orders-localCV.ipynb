# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import cudf
import glob
import gc

import pandas as pd

from tqdm import tqdm

# %%
def calc_recall(sub, ty='clicks', file='./data/xgb_train_y.parquet'):
    sub = sub.sort_values(['session', 'score'], ascending=[True, False])
    sub['dummy'] = 1
    sub['rank'] = sub.groupby(['session']).dummy.cumsum()
    sub.drop(['dummy'], axis=1, inplace=True)
    sub = sub[sub['rank']<21]
    sub = sub[['session', 'cand']]
    sub.columns = ['session', 'aid']
    test_labels = cudf.read_parquet(file)
    test_labels = test_labels[test_labels['type']==ty]
    test_labels = test_labels.merge(
        test_labels.groupby(['session', 'type']).count().reset_index().rename(columns={'aid': 'no_gt'}),
        how='left',
        on=['session', 'type']
    )
    sub['target'] = 1
    sub.columns = ['session', 'aid', 'target']
    test_labels = test_labels.merge(
        sub[['session', 'aid', 'target']].drop_duplicates(['session', 'aid']),
        how='left',
        on=['session', 'aid']

    )
    test_labels['target'] = test_labels['target'].fillna(0)
    test_labels = test_labels[test_labels['session'].isin(sub['session'])]
    test_labels = test_labels.groupby(['session', 'aid']).agg({'no_gt': 'min', 'target': 'sum'}).reset_index()
    recall = test_labels.target.sum()/test_labels.groupby(['session']).no_gt.min().clip(0,20).sum()
    print(recall)
    return(recall, test_labels.target.sum(), test_labels.groupby(['session']).no_gt.min().clip(0,20).sum())

# %%
# !ls ./data/split/chunks_c_2/
# Out:
# ls: cannot access './data/split/chunks_c_2/': No such file or directory

# %%
import xgboost as xgb

xgb_parms = { 
    'max_depth':8, 
    'learning_rate':0.1, 
    'subsample':0.8,
    'colsample_bytree':0.3, 
    'eval_metric':'logloss',
    'objective':'binary:logistic',
    'tree_method':'gpu_hist' 
}

bl_sub = False
bl_pos = True
outputfolder = '24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v9'
no_seeds = 3
no_trees = 1000

# %%
ty = 'orders'
labels = cudf.read_parquet('./data/xgb_train_y.parquet')
labels.columns = ['session', 'cand', 'type']
labels['target'] = 1

# %%
files = sorted(glob.glob('./data/split/chunks/' + ty + '/chunk*.parquet'))
files
# Out:
# ['./data/split/chunks/orders/chunk_0.parquet',
#  './data/split/chunks/orders/chunk_1.parquet']

# %%
[y for x in [
    sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
    for igfold2 in range(0,5)
] for y in x ]
# Out:
# ['./data_folds/fold_0/split/chunks/orders/chunk_0.parquet',
#  './data_folds/fold_0/split/chunks/orders/chunk_1.parquet',
#  './data_folds/fold_1/split/chunks/orders/chunk_0.parquet',
#  './data_folds/fold_1/split/chunks/orders/chunk_1.parquet',
#  './data_folds/fold_2/split/chunks/orders/chunk_0.parquet',
#  './data_folds/fold_2/split/chunks/orders/chunk_1.parquet',
#  './data_folds/fold_3/split/chunks/orders/chunk_0.parquet',
#  './data_folds/fold_3/split/chunks/orders/chunk_1.parquet',
#  './data_folds/fold_4/split/chunks/orders/chunk_0.parquet',
#  './data_folds/fold_4/split/chunks/orders/chunk_1.parquet']

# %%
#session_filter = labels[(labels['type']=='orders')]['session'].drop_duplicates().to_pandas().tolist()

# %%
ingore_cols = []

# %%
# %%time

model_bests = []
hist_recall = []
total_no_hit = 0
total_no_gt = 0
for igfold in range(5):
    files = sorted(glob.glob('./data_folds/fold_' + str(igfold) + '/split/chunks_c_2/' + ty + '/chunk*.parquet'))
    print(files)
    for ifile, file in enumerate(files):
        if bl_sub:
            if ty == 'clicks':
                test_files = []
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
            elif ty == 'carts':
                test_files = []
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
            elif ty == 'orders':
                test_files = []
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
            else:
                assert 0!=0
            if ty == 'clicks':
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
            elif ty == 'carts':
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
            elif ty == 'orders':
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
        else:
            if ty == 'clicks':
                test_files = files[ifile]
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
            elif ty == 'carts':
                test_files = files[ifile]
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
            elif ty == 'orders':
                test_files = files[ifile]
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
            else:
                assert 0!=0
            
            if ty == 'clicks':
                train_files = [
                    y for x in [
                        sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks_c_2/' + ty + '/chunk*.parquet'))
                        for igfold2 in range(0,5)
                    ] for y in x if y not in test_files][0:2]
            elif ty == 'carts':
                train_files = [
                    y for x in [
                        sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks_c_2/' + ty + '/chunk*.parquet'))
                        for igfold2 in range(0,5)
                    ] for y in x if y not in test_files][0:5]
            else:
                train_files = [
                    y for x in [
                        sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks_c_2/' + ty + '/chunk*.parquet'))
                        for igfold2 in range(0,5)
                    ] for y in x if y not in test_files]
            
            if ty == 'clicks':
                df_test = pd.read_parquet(test_files)
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
            elif ty == 'carts':
                df_test = pd.read_parquet(test_files)
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
            elif ty == 'orders':
                df_test = pd.read_parquet(test_files)
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])

        print(train_files)
        print(test_files)

        if bl_pos and ty!='clicks':
            df_train = df_train[df_train['session'].isin(
                df_train[df_train['target']==1]['session'].drop_duplicates().values
            )]
        
        print(df_train.shape)

        train_cols = [x for x in df_train.columns if x not in [
            'session', 'cand', 'target', 'target_clicks', 'target_carts', 'target_orders'
        ] + ingore_cols]

        print('Recall Train: ' + str(df_train[df_train['target']==1].shape[0]/labels[
        (labels['session'].isin(df_train['session'].drop_duplicates()))&(labels['type']==ty)
    ].shape[0]))
        if not bl_sub:
            print('Recall Test: ' + str(df_test[df_test['target']==1].shape[0]/labels[
            (labels['session'].isin(df_test['session'].drop_duplicates()))&(labels['type']==ty)
        ].shape[0]))

        dtrain = xgb.DMatrix(data=df_train[train_cols].values,label=df_train['target'].values)
        if not bl_sub:
            dtest =  xgb.DMatrix(data=df_test[train_cols].values, label=df_test['target'].values)
            df_test['score'] = 0.0

        del df_train
        gc.collect()

        models = []
        for iseed in range(no_seeds):
            print('iseed: ' + str(iseed))
            xgb_parms['seed'] = iseed
            if bl_sub:
                model = xgb.train(
                    xgb_parms, 
                    dtrain=dtrain,
                    evals=[(dtrain,'train')],
                    num_boost_round=no_trees,
                    verbose_eval=10
                )
            else:
                model = xgb.train(
                    xgb_parms, 
                    dtrain=dtrain,
                    evals=[(dtest,'test')],
                    num_boost_round=no_trees,
                    verbose_eval=10,
                    early_stopping_rounds=50
                )
                df_test['score'] += model.predict(dtest)
                model_bests.append(model.best_iteration)
            models.append(model)
        del dtrain
        
        sub = cudf.from_pandas(df_test[['session', 'cand', 'score']])
        recall, no_hit, no_gt = calc_recall(sub, ty=ty)
        hist_recall.append(recall)
        total_no_hit += no_hit
        total_no_gt += no_gt
        print(total_no_hit/total_no_gt)

        del sub
        gc.collect()
# Out:
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet
# (17045999, 171)
# Recall Train: 0.7876550911485409
# Recall Test: 0.7337211181127807
# iseed: 0
# [0]	test-logloss:0.60039
# [10]	test-logloss:0.18959
# [20]	test-logloss:0.07821
# [30]	test-logloss:0.04159
# [40]	test-logloss:0.02919
# [50]	test-logloss:0.02503
# [60]	test-logloss:0.02366
# [70]	test-logloss:0.02320
# [80]	test-logloss:0.02301
# [90]	test-logloss:0.02291
# [100]	test-logloss:0.02286
# [110]	test-logloss:0.02284
# [120]	test-logloss:0.02281
# [130]	test-logloss:0.02280
# [140]	test-logloss:0.02278
# [150]	test-logloss:0.02277
# [160]	test-logloss:0.02276
# [170]	test-logloss:0.02275
# [180]	test-logloss:0.02274
# [190]	test-logloss:0.02273
# [200]	test-logloss:0.02273
# [210]	test-logloss:0.02272
# [220]	test-logloss:0.02272
# [230]	test-logloss:0.02272
# [240]	test-logloss:0.02272
# [250]	test-logloss:0.02271
# [260]	test-logloss:0.02271
# [270]	test-logloss:0.02271
# [280]	test-logloss:0.02271
# [290]	test-logloss:0.02270
# [300]	test-logloss:0.02270
# [310]	test-logloss:0.02270
# [320]	test-logloss:0.02270
# [330]	test-logloss:0.02271
# [340]	test-logloss:0.02271
# [350]	test-logloss:0.02271
# [360]	test-logloss:0.02270
# [366]	test-logloss:0.02270
# iseed: 1
# [0]	test-logloss:0.60037
# [10]	test-logloss:0.18958
# [20]	test-logloss:0.07816
# [30]	test-logloss:0.04156
# [40]	test-logloss:0.02915
# [50]	test-logloss:0.02501
# [60]	test-logloss:0.02365
# [70]	test-logloss:0.02320
# [80]	test-logloss:0.02301
# [90]	test-logloss:0.02293
# [100]	test-logloss:0.02288
# [110]	test-logloss:0.02284
# [120]	test-logloss:0.02282
# [130]	test-logloss:0.02279
# [140]	test-logloss:0.02278
# [150]	test-logloss:0.02276
# [160]	test-logloss:0.02276
# [170]	test-logloss:0.02274
# [180]	test-logloss:0.02273
# [190]	test-logloss:0.02273
# [200]	test-logloss:0.02272
# [210]	test-logloss:0.02272
# [220]	test-logloss:0.02271
# [230]	test-logloss:0.02271
# [240]	test-logloss:0.02270
# [250]	test-logloss:0.02270
# [260]	test-logloss:0.02270
# [270]	test-logloss:0.02270
# [280]	test-logloss:0.02269
# [290]	test-logloss:0.02270
# [300]	test-logloss:0.02270
# [310]	test-logloss:0.02269
# [320]	test-logloss:0.02270
# [330]	test-logloss:0.02270
# iseed: 2
# [0]	test-logloss:0.60042
# [10]	test-logloss:0.18951
# [20]	test-logloss:0.07815
# [30]	test-logloss:0.04154
# [40]	test-logloss:0.02916
# [50]	test-logloss:0.02499
# [60]	test-logloss:0.02364
# [70]	test-logloss:0.02317
# [80]	test-logloss:0.02300
# [90]	test-logloss:0.02291
# [100]	test-logloss:0.02287
# [110]	test-logloss:0.02284
# [120]	test-logloss:0.02281
# [130]	test-logloss:0.02279
# [140]	test-logloss:0.02278
# [150]	test-logloss:0.02278
# [160]	test-logloss:0.02277
# [170]	test-logloss:0.02276
# [180]	test-logloss:0.02275
# [190]	test-logloss:0.02274
# [200]	test-logloss:0.02273
# [210]	test-logloss:0.02272
# [220]	test-logloss:0.02272
# [230]	test-logloss:0.02272
# [240]	test-logloss:0.02271
# [250]	test-logloss:0.02271
# [260]	test-logloss:0.02271
# [270]	test-logloss:0.02271
# [280]	test-logloss:0.02270
# [290]	test-logloss:0.02270
# [300]	test-logloss:0.02270
# [310]	test-logloss:0.02270
# [320]	test-logloss:0.02270
# [330]	test-logloss:0.02270
# [340]	test-logloss:0.02270
# [350]	test-logloss:0.02270
# [360]	test-logloss:0.02270
# [370]	test-logloss:0.02270
# [372]	test-logloss:0.02270
# 0.6769834067928442
# 0.6769834067928442
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet
# (17009295, 171)
# Recall Train: 0.7889010297416572
# Recall Test: 0.7240998104864181
# iseed: 0
# [0]	test-logloss:0.60037
# [10]	test-logloss:0.18944
# [20]	test-logloss:0.07800
# [30]	test-logloss:0.04133
# [40]	test-logloss:0.02891
# [50]	test-logloss:0.02473
# [60]	test-logloss:0.02336
# [70]	test-logloss:0.02290
# [80]	test-logloss:0.02272
# [90]	test-logloss:0.02262
# [100]	test-logloss:0.02258
# [110]	test-logloss:0.02255
# [120]	test-logloss:0.02252
# [130]	test-logloss:0.02251
# [140]	test-logloss:0.02249
# [150]	test-logloss:0.02249
# [160]	test-logloss:0.02248
# [170]	test-logloss:0.02247
# [180]	test-logloss:0.02245
# [190]	test-logloss:0.02245
# [200]	test-logloss:0.02244
# [210]	test-logloss:0.02243
# [220]	test-logloss:0.02243
# [230]	test-logloss:0.02243
# [240]	test-logloss:0.02242
# [250]	test-logloss:0.02242
# [260]	test-logloss:0.02241
# [270]	test-logloss:0.02241
# [280]	test-logloss:0.02240
# [290]	test-logloss:0.02240
# [300]	test-logloss:0.02240
# [310]	test-logloss:0.02240
# [320]	test-logloss:0.02240
# [330]	test-logloss:0.02240
# [340]	test-logloss:0.02240
# [350]	test-logloss:0.02239
# [360]	test-logloss:0.02239
# [370]	test-logloss:0.02239
# [380]	test-logloss:0.02239
# [390]	test-logloss:0.02239
# [400]	test-logloss:0.02239
# [410]	test-logloss:0.02239
# [420]	test-logloss:0.02239
# [430]	test-logloss:0.02239
# [435]	test-logloss:0.02239
# iseed: 1
# [0]	test-logloss:0.60036
# [10]	test-logloss:0.18946
# [20]	test-logloss:0.07796
# [30]	test-logloss:0.04131
# [40]	test-logloss:0.02886
# [50]	test-logloss:0.02470
# [60]	test-logloss:0.02334
# [70]	test-logloss:0.02289
# [80]	test-logloss:0.02271
# [90]	test-logloss:0.02263
# [100]	test-logloss:0.02258
# [110]	test-logloss:0.02255
# [120]	test-logloss:0.02253
# [130]	test-logloss:0.02251
# [140]	test-logloss:0.02250
# [150]	test-logloss:0.02248
# [160]	test-logloss:0.02247
# [170]	test-logloss:0.02247
# [180]	test-logloss:0.02246
# [190]	test-logloss:0.02245
# [200]	test-logloss:0.02245
# [210]	test-logloss:0.02244
# [220]	test-logloss:0.02244
# [230]	test-logloss:0.02244
# [240]	test-logloss:0.02243
# [250]	test-logloss:0.02243
# [260]	test-logloss:0.02242
# [270]	test-logloss:0.02242
# [280]	test-logloss:0.02242
# [290]	test-logloss:0.02242
# [300]	test-logloss:0.02242
# [310]	test-logloss:0.02242
# [320]	test-logloss:0.02242
# [330]	test-logloss:0.02242
# [340]	test-logloss:0.02242
# [350]	test-logloss:0.02242
# [360]	test-logloss:0.02241
# [370]	test-logloss:0.02242
# [380]	test-logloss:0.02242
# [390]	test-logloss:0.02241
# [400]	test-logloss:0.02241
# [410]	test-logloss:0.02241
# iseed: 2
# [0]	test-logloss:0.60041
# [10]	test-logloss:0.18938
# [20]	test-logloss:0.07794
# [30]	test-logloss:0.04128
# [40]	test-logloss:0.02887
# [50]	test-logloss:0.02468
# [60]	test-logloss:0.02334
# [70]	test-logloss:0.02286
# [80]	test-logloss:0.02269
# [90]	test-logloss:0.02261
# [100]	test-logloss:0.02256
# [110]	test-logloss:0.02254
# [120]	test-logloss:0.02251
# [130]	test-logloss:0.02250
# [140]	test-logloss:0.02249
# [150]	test-logloss:0.02249
# [160]	test-logloss:0.02248
# [170]	test-logloss:0.02247
# [180]	test-logloss:0.02246
# [190]	test-logloss:0.02246
# [200]	test-logloss:0.02245
# [210]	test-logloss:0.02244
# [220]	test-logloss:0.02244
# [230]	test-logloss:0.02243
# [240]	test-logloss:0.02243
# [250]	test-logloss:0.02242
# [260]	test-logloss:0.02242
# [270]	test-logloss:0.02242
# [280]	test-logloss:0.02242
# [290]	test-logloss:0.02241
# [300]	test-logloss:0.02241
# [310]	test-logloss:0.02241
# [320]	test-logloss:0.02241
# [330]	test-logloss:0.02241
# [340]	test-logloss:0.02241
# [350]	test-logloss:0.02241
# [360]	test-logloss:0.02241
# [370]	test-logloss:0.02241
# [380]	test-logloss:0.02241
# [390]	test-logloss:0.02241
# [400]	test-logloss:0.02241
# [403]	test-logloss:0.02241
# 0.6689593964943421
# 0.6729268488101915
# ['./data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet
# (17048625, 171)
# Recall Train: 0.7882866566993942
# Recall Test: 0.7280929903991266
# iseed: 0
# [0]	test-logloss:0.60038
# [10]	test-logloss:0.18950
# [20]	test-logloss:0.07809
# [30]	test-logloss:0.04142
# [40]	test-logloss:0.02900
# [50]	test-logloss:0.02483
# [60]	test-logloss:0.02345
# [70]	test-logloss:0.02298
# [80]	test-logloss:0.02279
# [90]	test-logloss:0.02270
# [100]	test-logloss:0.02264
# [110]	test-logloss:0.02261
# [120]	test-logloss:0.02258
# [130]	test-logloss:0.02256
# [140]	test-logloss:0.02254
# [150]	test-logloss:0.02253
# [160]	test-logloss:0.02252
# [170]	test-logloss:0.02251
# [180]	test-logloss:0.02250
# [190]	test-logloss:0.02249
# [200]	test-logloss:0.02248
# [210]	test-logloss:0.02247
# [220]	test-logloss:0.02247
# [230]	test-logloss:0.02246
# [240]	test-logloss:0.02246
# [250]	test-logloss:0.02245
# [260]	test-logloss:0.02245
# [270]	test-logloss:0.02244
# [280]	test-logloss:0.02244
# [290]	test-logloss:0.02244
# [300]	test-logloss:0.02244
# [310]	test-logloss:0.02243
# [320]	test-logloss:0.02243
# [330]	test-logloss:0.02243
# [340]	test-logloss:0.02244
# [350]	test-logloss:0.02243
# [360]	test-logloss:0.02244
# [370]	test-logloss:0.02244
# [380]	test-logloss:0.02243
# [382]	test-logloss:0.02244
# iseed: 1
# [0]	test-logloss:0.60036
# [10]	test-logloss:0.18949
# [20]	test-logloss:0.07803
# [30]	test-logloss:0.04139
# [40]	test-logloss:0.02895
# [50]	test-logloss:0.02479
# [60]	test-logloss:0.02342
# [70]	test-logloss:0.02297
# [80]	test-logloss:0.02278
# [90]	test-logloss:0.02269
# [100]	test-logloss:0.02263
# [110]	test-logloss:0.02260
# [120]	test-logloss:0.02258
# [130]	test-logloss:0.02256
# [140]	test-logloss:0.02254
# [150]	test-logloss:0.02253
# [160]	test-logloss:0.02252
# [170]	test-logloss:0.02251
# [180]	test-logloss:0.02250
# [190]	test-logloss:0.02249
# [200]	test-logloss:0.02249
# [210]	test-logloss:0.02248
# [220]	test-logloss:0.02247
# [230]	test-logloss:0.02247
# [240]	test-logloss:0.02247
# [250]	test-logloss:0.02247
# [260]	test-logloss:0.02246
# [270]	test-logloss:0.02246
# [280]	test-logloss:0.02246
# [290]	test-logloss:0.02245
# [300]	test-logloss:0.02245
# [310]	test-logloss:0.02245
# [320]	test-logloss:0.02245
# [330]	test-logloss:0.02245
# [340]	test-logloss:0.02244
# [350]	test-logloss:0.02244
# [360]	test-logloss:0.02244
# [370]	test-logloss:0.02244
# [380]	test-logloss:0.02244
# [390]	test-logloss:0.02244
# [400]	test-logloss:0.02244
# [410]	test-logloss:0.02244
# [420]	test-logloss:0.02244
# [430]	test-logloss:0.02245
# [440]	test-logloss:0.02245
# [450]	test-logloss:0.02245
# [452]	test-logloss:0.02245
# iseed: 2
# [0]	test-logloss:0.60042
# [10]	test-logloss:0.18942
# [20]	test-logloss:0.07801
# [30]	test-logloss:0.04137
# [40]	test-logloss:0.02898
# [50]	test-logloss:0.02478
# [60]	test-logloss:0.02344
# [70]	test-logloss:0.02296
# [80]	test-logloss:0.02278
# [90]	test-logloss:0.02270
# [100]	test-logloss:0.02265
# [110]	test-logloss:0.02261
# [120]	test-logloss:0.02258
# [130]	test-logloss:0.02256
# [140]	test-logloss:0.02254
# [150]	test-logloss:0.02253
# [160]	test-logloss:0.02252
# [170]	test-logloss:0.02251
# [180]	test-logloss:0.02250
# [190]	test-logloss:0.02249
# [200]	test-logloss:0.02248
# [210]	test-logloss:0.02248
# [220]	test-logloss:0.02247
# [230]	test-logloss:0.02247
# [240]	test-logloss:0.02247
# [250]	test-logloss:0.02246
# [260]	test-logloss:0.02246
# [270]	test-logloss:0.02245
# [280]	test-logloss:0.02245
# [290]	test-logloss:0.02245
# [300]	test-logloss:0.02245
# [310]	test-logloss:0.02244
# [320]	test-logloss:0.02244
# [330]	test-logloss:0.02244
# [340]	test-logloss:0.02244
# [350]	test-logloss:0.02243
# [360]	test-logloss:0.02244
# [370]	test-logloss:0.02244
# [380]	test-logloss:0.02244
# [390]	test-logloss:0.02243
# [400]	test-logloss:0.02243
# [410]	test-logloss:0.02243
# [420]	test-logloss:0.02243
# [430]	test-logloss:0.02243
# [440]	test-logloss:0.02244
# [450]	test-logloss:0.02244
# [460]	test-logloss:0.02244
# [462]	test-logloss:0.02244
# 0.6749541077582042
# 0.6736004108885465
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet
# (17059432, 171)
# Recall Train: 0.7875578730407765
# Recall Test: 0.7347914347455963
# iseed: 0
# [0]	test-logloss:0.60037
# [10]	test-logloss:0.18951
# [20]	test-logloss:0.07809
# [30]	test-logloss:0.04144
# [40]	test-logloss:0.02903
# [50]	test-logloss:0.02488
# [60]	test-logloss:0.02352
# [70]	test-logloss:0.02307
# [80]	test-logloss:0.02290
# [90]	test-logloss:0.02281
# [100]	test-logloss:0.02277
# [110]	test-logloss:0.02274
# [120]	test-logloss:0.02272
# [130]	test-logloss:0.02270
# [140]	test-logloss:0.02269
# [150]	test-logloss:0.02267
# [160]	test-logloss:0.02267
# [170]	test-logloss:0.02265
# [180]	test-logloss:0.02265
# [190]	test-logloss:0.02264
# [200]	test-logloss:0.02263
# [210]	test-logloss:0.02263
# [220]	test-logloss:0.02262
# [230]	test-logloss:0.02262
# [240]	test-logloss:0.02261
# [250]	test-logloss:0.02261
# [260]	test-logloss:0.02261
# [270]	test-logloss:0.02261
# [280]	test-logloss:0.02261
# [290]	test-logloss:0.02260
# [300]	test-logloss:0.02260
# [310]	test-logloss:0.02260
# [320]	test-logloss:0.02260
# [330]	test-logloss:0.02260
# [340]	test-logloss:0.02259
# [350]	test-logloss:0.02260
# [360]	test-logloss:0.02260
# [370]	test-logloss:0.02260
# [380]	test-logloss:0.02260
# [390]	test-logloss:0.02260
# iseed: 1
# [0]	test-logloss:0.60036
# [10]	test-logloss:0.18950
# [20]	test-logloss:0.07803
# [30]	test-logloss:0.04141
# [40]	test-logloss:0.02900
# [50]	test-logloss:0.02486
# [60]	test-logloss:0.02351
# [70]	test-logloss:0.02307
# [80]	test-logloss:0.02290
# [90]	test-logloss:0.02282
# [100]	test-logloss:0.02277
# [110]	test-logloss:0.02274
# [120]	test-logloss:0.02271
# [130]	test-logloss:0.02269
# [140]	test-logloss:0.02268
# [150]	test-logloss:0.02267
# [160]	test-logloss:0.02266
# [170]	test-logloss:0.02266
# [180]	test-logloss:0.02265
# [190]	test-logloss:0.02265
# [200]	test-logloss:0.02264
# [210]	test-logloss:0.02264
# [220]	test-logloss:0.02263
# [230]	test-logloss:0.02263
# [240]	test-logloss:0.02263
# [250]	test-logloss:0.02263
# [260]	test-logloss:0.02263
# [270]	test-logloss:0.02263
# [280]	test-logloss:0.02263
# [290]	test-logloss:0.02263
# [300]	test-logloss:0.02263
# [310]	test-logloss:0.02262
# [320]	test-logloss:0.02262
# [330]	test-logloss:0.02262
# [340]	test-logloss:0.02262
# [350]	test-logloss:0.02262
# [360]	test-logloss:0.02262
# [370]	test-logloss:0.02262
# [380]	test-logloss:0.02262
# [390]	test-logloss:0.02261
# [400]	test-logloss:0.02262
# [410]	test-logloss:0.02262
# [420]	test-logloss:0.02262
# [430]	test-logloss:0.02263
# [439]	test-logloss:0.02263
# iseed: 2
# [0]	test-logloss:0.60043
# [10]	test-logloss:0.18943
# [20]	test-logloss:0.07803
# [30]	test-logloss:0.04140
# [40]	test-logloss:0.02901
# [50]	test-logloss:0.02485
# [60]	test-logloss:0.02352
# [70]	test-logloss:0.02306
# [80]	test-logloss:0.02290
# [90]	test-logloss:0.02281
# [100]	test-logloss:0.02276
# [110]	test-logloss:0.02273
# [120]	test-logloss:0.02270
# [130]	test-logloss:0.02269
# [140]	test-logloss:0.02268
# [150]	test-logloss:0.02267
# [160]	test-logloss:0.02266
# [170]	test-logloss:0.02264
# [180]	test-logloss:0.02264
# [190]	test-logloss:0.02263
# [200]	test-logloss:0.02263
# [210]	test-logloss:0.02262
# [220]	test-logloss:0.02262
# [230]	test-logloss:0.02262
# [240]	test-logloss:0.02261
# [250]	test-logloss:0.02261
# [260]	test-logloss:0.02261
# [270]	test-logloss:0.02261
# [280]	test-logloss:0.02260
# [290]	test-logloss:0.02260
# [300]	test-logloss:0.02259
# [310]	test-logloss:0.02259
# [320]	test-logloss:0.02259
# [330]	test-logloss:0.02259
# [340]	test-logloss:0.02260
# [350]	test-logloss:0.02260
# [355]	test-logloss:0.02260
# 0.6778743644415286
# 0.6746516487683656
# ['./data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet
# (17037836, 171)
# Recall Train: 0.7885434723987826
# Recall Test: 0.7218772008451245
# iseed: 0
# [0]	test-logloss:0.60037
# [10]	test-logloss:0.18944
# [20]	test-logloss:0.07801
# [30]	test-logloss:0.04138
# [40]	test-logloss:0.02898
# [50]	test-logloss:0.02484
# [60]	test-logloss:0.02349
# [70]	test-logloss:0.02304
# [80]	test-logloss:0.02286
# [90]	test-logloss:0.02276
# [100]	test-logloss:0.02271
# [110]	test-logloss:0.02268
# [120]	test-logloss:0.02266
# [130]	test-logloss:0.02265
# [140]	test-logloss:0.02264
# [150]	test-logloss:0.02263
# [160]	test-logloss:0.02262
# [170]	test-logloss:0.02261
# [180]	test-logloss:0.02260
# [190]	test-logloss:0.02259
# [200]	test-logloss:0.02259
# [210]	test-logloss:0.02258
# [220]	test-logloss:0.02257
# [230]	test-logloss:0.02256
# [240]	test-logloss:0.02256
# [250]	test-logloss:0.02256
# [260]	test-logloss:0.02255
# [270]	test-logloss:0.02255
# [280]	test-logloss:0.02254
# [290]	test-logloss:0.02254
# [300]	test-logloss:0.02255
# [310]	test-logloss:0.02255
# [320]	test-logloss:0.02255
# [325]	test-logloss:0.02255
# iseed: 1
# [0]	test-logloss:0.60035
# [10]	test-logloss:0.18945
# [20]	test-logloss:0.07797
# [30]	test-logloss:0.04135
# [40]	test-logloss:0.02894
# [50]	test-logloss:0.02481
# [60]	test-logloss:0.02347
# [70]	test-logloss:0.02303
# [80]	test-logloss:0.02284
# [90]	test-logloss:0.02276
# [100]	test-logloss:0.02271
# [110]	test-logloss:0.02268
# [120]	test-logloss:0.02266
# [130]	test-logloss:0.02264
# [140]	test-logloss:0.02262
# [150]	test-logloss:0.02260
# [160]	test-logloss:0.02259
# [170]	test-logloss:0.02258
# [180]	test-logloss:0.02258
# [190]	test-logloss:0.02257
# [200]	test-logloss:0.02256
# [210]	test-logloss:0.02255
# [220]	test-logloss:0.02255
# [230]	test-logloss:0.02255
# [240]	test-logloss:0.02254
# [250]	test-logloss:0.02254
# [260]	test-logloss:0.02253
# [270]	test-logloss:0.02253
# [280]	test-logloss:0.02253
# [290]	test-logloss:0.02252
# [300]	test-logloss:0.02252
# [310]	test-logloss:0.02252
# [320]	test-logloss:0.02252
# [330]	test-logloss:0.02253
# [340]	test-logloss:0.02253
# [350]	test-logloss:0.02253
# [357]	test-logloss:0.02253
# iseed: 2
# [0]	test-logloss:0.60042
# [10]	test-logloss:0.18938
# [20]	test-logloss:0.07796
# [30]	test-logloss:0.04133
# [40]	test-logloss:0.02896
# [50]	test-logloss:0.02480
# [60]	test-logloss:0.02348
# [70]	test-logloss:0.02301
# [80]	test-logloss:0.02285
# [90]	test-logloss:0.02277
# [100]	test-logloss:0.02272
# [110]	test-logloss:0.02269
# [120]	test-logloss:0.02266
# [130]	test-logloss:0.02265
# [140]	test-logloss:0.02264
# [150]	test-logloss:0.02263
# [160]	test-logloss:0.02262
# [170]	test-logloss:0.02261
# [180]	test-logloss:0.02260
# [190]	test-logloss:0.02259
# [200]	test-logloss:0.02258
# [210]	test-logloss:0.02257
# [220]	test-logloss:0.02257
# [230]	test-logloss:0.02257
# [240]	test-logloss:0.02256
# [250]	test-logloss:0.02256
# [260]	test-logloss:0.02256
# [270]	test-logloss:0.02255
# [280]	test-logloss:0.02255
# [290]	test-logloss:0.02255
# [300]	test-logloss:0.02256
# [310]	test-logloss:0.02256
# [320]	test-logloss:0.02255
# [330]	test-logloss:0.02255
# [340]	test-logloss:0.02255
# [350]	test-logloss:0.02255
# [360]	test-logloss:0.02256
# [370]	test-logloss:0.02255
# [380]	test-logloss:0.02255
# [385]	test-logloss:0.02255
# 0.6661103443848895
# 0.6729358212227108
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet
# (17053276, 171)
# Recall Train: 0.7881481823569708
# Recall Test: 0.7259618493372131
# iseed: 0
# [0]	test-logloss:0.60037
# [10]	test-logloss:0.18945
# [20]	test-logloss:0.07803
# [30]	test-logloss:0.04139
# [40]	test-logloss:0.02899
# [50]	test-logloss:0.02484
# [60]	test-logloss:0.02349
# [70]	test-logloss:0.02305
# [80]	test-logloss:0.02287
# [90]	test-logloss:0.02277
# [100]	test-logloss:0.02272
# [110]	test-logloss:0.02268
# [120]	test-logloss:0.02266
# [130]	test-logloss:0.02264
# [140]	test-logloss:0.02262
# [150]	test-logloss:0.02261
# [160]	test-logloss:0.02260
# [170]	test-logloss:0.02259
# [180]	test-logloss:0.02258
# [190]	test-logloss:0.02257
# [200]	test-logloss:0.02257
# [210]	test-logloss:0.02257
# [220]	test-logloss:0.02256
# [230]	test-logloss:0.02256
# [240]	test-logloss:0.02256
# [250]	test-logloss:0.02256
# [260]	test-logloss:0.02256
# [270]	test-logloss:0.02256
# [280]	test-logloss:0.02255
# [290]	test-logloss:0.02255
# [300]	test-logloss:0.02255
# [310]	test-logloss:0.02255
# [320]	test-logloss:0.02255
# [330]	test-logloss:0.02255
# [340]	test-logloss:0.02255
# [350]	test-logloss:0.02254
# [360]	test-logloss:0.02254
# [370]	test-logloss:0.02254
# [380]	test-logloss:0.02254
# [390]	test-logloss:0.02254
# [400]	test-logloss:0.02254
# [410]	test-logloss:0.02255
# [417]	test-logloss:0.02255
# iseed: 1
# [0]	test-logloss:0.60035
# [10]	test-logloss:0.18946
# [20]	test-logloss:0.07799
# [30]	test-logloss:0.04137
# [40]	test-logloss:0.02895
# [50]	test-logloss:0.02482
# [60]	test-logloss:0.02348
# [70]	test-logloss:0.02304
# [80]	test-logloss:0.02286
# [90]	test-logloss:0.02278
# [100]	test-logloss:0.02272
# [110]	test-logloss:0.02269
# [120]	test-logloss:0.02267
# [130]	test-logloss:0.02265
# [140]	test-logloss:0.02263
# [150]	test-logloss:0.02262
# [160]	test-logloss:0.02261
# [170]	test-logloss:0.02261
# [180]	test-logloss:0.02260
# [190]	test-logloss:0.02259
# [200]	test-logloss:0.02259
# [210]	test-logloss:0.02258
# [220]	test-logloss:0.02258
# [230]	test-logloss:0.02257
# [240]	test-logloss:0.02257
# [250]	test-logloss:0.02256
# [260]	test-logloss:0.02256
# [270]	test-logloss:0.02256
# [280]	test-logloss:0.02255
# [290]	test-logloss:0.02255
# [300]	test-logloss:0.02255
# [310]	test-logloss:0.02255
# [320]	test-logloss:0.02255
# [330]	test-logloss:0.02255
# [340]	test-logloss:0.02255
# [348]	test-logloss:0.02255
# iseed: 2
# [0]	test-logloss:0.60041
# [10]	test-logloss:0.18939
# [20]	test-logloss:0.07798
# [30]	test-logloss:0.04136
# [40]	test-logloss:0.02898
# [50]	test-logloss:0.02482
# [60]	test-logloss:0.02350
# [70]	test-logloss:0.02303
# [80]	test-logloss:0.02287
# [90]	test-logloss:0.02278
# [100]	test-logloss:0.02273
# [110]	test-logloss:0.02270
# [120]	test-logloss:0.02268
# [130]	test-logloss:0.02266
# [140]	test-logloss:0.02265
# [150]	test-logloss:0.02264
# [160]	test-logloss:0.02262
# [170]	test-logloss:0.02261
# [180]	test-logloss:0.02260
# [190]	test-logloss:0.02259
# [200]	test-logloss:0.02259
# [210]	test-logloss:0.02259
# [220]	test-logloss:0.02258
# [230]	test-logloss:0.02258
# [240]	test-logloss:0.02257
# [250]	test-logloss:0.02257
# [260]	test-logloss:0.02256
# [270]	test-logloss:0.02256
# [280]	test-logloss:0.02255
# [290]	test-logloss:0.02255
# [300]	test-logloss:0.02255
# [310]	test-logloss:0.02255
# [320]	test-logloss:0.02256
# [330]	test-logloss:0.02256
# [335]	test-logloss:0.02255
# 0.6681887366818874
# 0.6721476311586917
# ['./data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet
# (17056920, 171)
# Recall Train: 0.7878238162364523
# Recall Test: 0.7327931301652892
# iseed: 0
# [0]	test-logloss:0.60040
# [10]	test-logloss:0.18957
# [20]	test-logloss:0.07817
# [30]	test-logloss:0.04154
# [40]	test-logloss:0.02914
# [50]	test-logloss:0.02499
# [60]	test-logloss:0.02363
# [70]	test-logloss:0.02318
# [80]	test-logloss:0.02301
# [90]	test-logloss:0.02292
# [100]	test-logloss:0.02287
# [110]	test-logloss:0.02284
# [120]	test-logloss:0.02282
# [130]	test-logloss:0.02280
# [140]	test-logloss:0.02278
# [150]	test-logloss:0.02277
# [160]	test-logloss:0.02276
# [170]	test-logloss:0.02276
# [180]	test-logloss:0.02274
# [190]	test-logloss:0.02273
# [200]	test-logloss:0.02273
# [210]	test-logloss:0.02272
# [220]	test-logloss:0.02272
# [230]	test-logloss:0.02272
# [240]	test-logloss:0.02272
# [250]	test-logloss:0.02272
# [260]	test-logloss:0.02271
# [270]	test-logloss:0.02271
# [280]	test-logloss:0.02270
# [290]	test-logloss:0.02270
# [300]	test-logloss:0.02270
# [310]	test-logloss:0.02270
# [320]	test-logloss:0.02270
# [330]	test-logloss:0.02270
# [340]	test-logloss:0.02270
# [350]	test-logloss:0.02270
# [360]	test-logloss:0.02269
# [370]	test-logloss:0.02269
# [380]	test-logloss:0.02269
# [390]	test-logloss:0.02269
# [400]	test-logloss:0.02269
# [410]	test-logloss:0.02269
# [420]	test-logloss:0.02269
# [430]	test-logloss:0.02269
# [431]	test-logloss:0.02269
# iseed: 1
# [0]	test-logloss:0.60038
# [10]	test-logloss:0.18957
# [20]	test-logloss:0.07812
# [30]	test-logloss:0.04151
# [40]	test-logloss:0.02909
# [50]	test-logloss:0.02495
# [60]	test-logloss:0.02360
# [70]	test-logloss:0.02316
# [80]	test-logloss:0.02299
# [90]	test-logloss:0.02290
# [100]	test-logloss:0.02285
# [110]	test-logloss:0.02281
# [120]	test-logloss:0.02278
# [130]	test-logloss:0.02277
# [140]	test-logloss:0.02276
# [150]	test-logloss:0.02275
# [160]	test-logloss:0.02274
# [170]	test-logloss:0.02273
# [180]	test-logloss:0.02271
# [190]	test-logloss:0.02271
# [200]	test-logloss:0.02270
# [210]	test-logloss:0.02270
# [220]	test-logloss:0.02270
# [230]	test-logloss:0.02270
# [240]	test-logloss:0.02269
# [250]	test-logloss:0.02269
# [260]	test-logloss:0.02268
# [270]	test-logloss:0.02268
# [280]	test-logloss:0.02268
# [290]	test-logloss:0.02267
# [300]	test-logloss:0.02267
# [310]	test-logloss:0.02267
# [320]	test-logloss:0.02267
# [330]	test-logloss:0.02267
# [340]	test-logloss:0.02267
# [350]	test-logloss:0.02267
# [360]	test-logloss:0.02267
# [368]	test-logloss:0.02267
# iseed: 2
# [0]	test-logloss:0.60045
# [10]	test-logloss:0.18950
# [20]	test-logloss:0.07811
# [30]	test-logloss:0.04149
# [40]	test-logloss:0.02911
# [50]	test-logloss:0.02494
# [60]	test-logloss:0.02362
# [70]	test-logloss:0.02315
# [80]	test-logloss:0.02299
# [90]	test-logloss:0.02291
# [100]	test-logloss:0.02286
# [110]	test-logloss:0.02283
# [120]	test-logloss:0.02281
# [130]	test-logloss:0.02280
# [140]	test-logloss:0.02278
# [150]	test-logloss:0.02277
# [160]	test-logloss:0.02276
# [170]	test-logloss:0.02276
# [180]	test-logloss:0.02275
# [190]	test-logloss:0.02274
# [200]	test-logloss:0.02274
# [210]	test-logloss:0.02273
# [220]	test-logloss:0.02273
# [230]	test-logloss:0.02273
# [240]	test-logloss:0.02272
# [250]	test-logloss:0.02272
# [260]	test-logloss:0.02272
# [270]	test-logloss:0.02271
# [280]	test-logloss:0.02271
# [290]	test-logloss:0.02271
# [300]	test-logloss:0.02271
# [310]	test-logloss:0.02271
# [320]	test-logloss:0.02271
# [330]	test-logloss:0.02271
# [340]	test-logloss:0.02271
# [350]	test-logloss:0.02271
# [360]	test-logloss:0.02271
# [370]	test-logloss:0.02271
# [380]	test-logloss:0.02271
# [390]	test-logloss:0.02272
# [400]	test-logloss:0.02272
# [401]	test-logloss:0.02272
# 0.6762867230265928
# 0.6727369149181461
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet
# (17024682, 171)
# Recall Train: 0.7883047338532772
# Recall Test: 0.7271914418010538
# iseed: 0
# [0]	test-logloss:0.60039
# [10]	test-logloss:0.18955
# [20]	test-logloss:0.07814
# [30]	test-logloss:0.04151
# [40]	test-logloss:0.02911
# [50]	test-logloss:0.02494
# [60]	test-logloss:0.02358
# [70]	test-logloss:0.02311
# [80]	test-logloss:0.02293
# [90]	test-logloss:0.02283
# [100]	test-logloss:0.02278
# [110]	test-logloss:0.02275
# [120]	test-logloss:0.02273
# [130]	test-logloss:0.02271
# [140]	test-logloss:0.02270
# [150]	test-logloss:0.02269
# [160]	test-logloss:0.02268
# [170]	test-logloss:0.02267
# [180]	test-logloss:0.02267
# [190]	test-logloss:0.02266
# [200]	test-logloss:0.02266
# [210]	test-logloss:0.02265
# [220]	test-logloss:0.02265
# [230]	test-logloss:0.02265
# [240]	test-logloss:0.02264
# [250]	test-logloss:0.02264
# [260]	test-logloss:0.02263
# [270]	test-logloss:0.02263
# [280]	test-logloss:0.02263
# [290]	test-logloss:0.02262
# [300]	test-logloss:0.02262
# [310]	test-logloss:0.02262
# [320]	test-logloss:0.02262
# [330]	test-logloss:0.02262
# [340]	test-logloss:0.02262
# [350]	test-logloss:0.02262
# [360]	test-logloss:0.02262
# [370]	test-logloss:0.02262
# [380]	test-logloss:0.02262
# [389]	test-logloss:0.02262
# iseed: 1
# [0]	test-logloss:0.60037
# [10]	test-logloss:0.18954
# [20]	test-logloss:0.07810
# [30]	test-logloss:0.04149
# [40]	test-logloss:0.02906
# [50]	test-logloss:0.02492
# [60]	test-logloss:0.02355
# [70]	test-logloss:0.02310
# [80]	test-logloss:0.02292
# [90]	test-logloss:0.02283
# [100]	test-logloss:0.02277
# [110]	test-logloss:0.02275
# [120]	test-logloss:0.02273
# [130]	test-logloss:0.02271
# [140]	test-logloss:0.02269
# [150]	test-logloss:0.02268
# [160]	test-logloss:0.02267
# [170]	test-logloss:0.02265
# [180]	test-logloss:0.02264
# [190]	test-logloss:0.02264
# [200]	test-logloss:0.02263
# [210]	test-logloss:0.02263
# [220]	test-logloss:0.02263
# [230]	test-logloss:0.02262
# [240]	test-logloss:0.02262
# [250]	test-logloss:0.02261
# [260]	test-logloss:0.02261
# [270]	test-logloss:0.02260
# [280]	test-logloss:0.02260
# [290]	test-logloss:0.02260
# [300]	test-logloss:0.02260
# [310]	test-logloss:0.02260
# [320]	test-logloss:0.02260
# [330]	test-logloss:0.02259
# [340]	test-logloss:0.02259
# [350]	test-logloss:0.02259
# [360]	test-logloss:0.02260
# [370]	test-logloss:0.02260
# [380]	test-logloss:0.02259
# [390]	test-logloss:0.02259
# [400]	test-logloss:0.02259
# [410]	test-logloss:0.02260
# [420]	test-logloss:0.02260
# [429]	test-logloss:0.02260
# iseed: 2
# [0]	test-logloss:0.60043
# [10]	test-logloss:0.18947
# [20]	test-logloss:0.07809
# [30]	test-logloss:0.04146
# [40]	test-logloss:0.02908
# [50]	test-logloss:0.02490
# [60]	test-logloss:0.02356
# [70]	test-logloss:0.02308
# [80]	test-logloss:0.02291
# [90]	test-logloss:0.02282
# [100]	test-logloss:0.02277
# [110]	test-logloss:0.02273
# [120]	test-logloss:0.02271
# [130]	test-logloss:0.02269
# [140]	test-logloss:0.02267
# [150]	test-logloss:0.02266
# [160]	test-logloss:0.02265
# [170]	test-logloss:0.02264
# [180]	test-logloss:0.02263
# [190]	test-logloss:0.02263
# [200]	test-logloss:0.02263
# [210]	test-logloss:0.02262
# [220]	test-logloss:0.02262
# [230]	test-logloss:0.02261
# [240]	test-logloss:0.02261
# [250]	test-logloss:0.02261
# [260]	test-logloss:0.02260
# [270]	test-logloss:0.02260
# [280]	test-logloss:0.02259
# [290]	test-logloss:0.02259
# [300]	test-logloss:0.02259
# [310]	test-logloss:0.02259
# [320]	test-logloss:0.02259
# [330]	test-logloss:0.02259
# [340]	test-logloss:0.02259
# [350]	test-logloss:0.02259
# [360]	test-logloss:0.02259
# [370]	test-logloss:0.02259
# [380]	test-logloss:0.02259
# [390]	test-logloss:0.02259
# [400]	test-logloss:0.02259
# [410]	test-logloss:0.02259
# [420]	test-logloss:0.02259
# [430]	test-logloss:0.02259
# [432]	test-logloss:0.02259
# 0.6713974498622413
# 0.6725683694530443
# ['./data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet']
# ./data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet
# (17015015, 171)
# Recall Train: 0.7881116287694412
# Recall Test: 0.7332996749865892
# iseed: 0
# [0]	test-logloss:0.60038
# [10]	test-logloss:0.18955
# [20]	test-logloss:0.07816
# [30]	test-logloss:0.04155
# [40]	test-logloss:0.02916
# [50]	test-logloss:0.02502
# [60]	test-logloss:0.02367
# [70]	test-logloss:0.02322
# [80]	test-logloss:0.02304
# [90]	test-logloss:0.02294
# [100]	test-logloss:0.02289
# [110]	test-logloss:0.02285
# [120]	test-logloss:0.02283
# [130]	test-logloss:0.02281
# [140]	test-logloss:0.02279
# [150]	test-logloss:0.02278
# [160]	test-logloss:0.02277
# [170]	test-logloss:0.02276
# [180]	test-logloss:0.02275
# [190]	test-logloss:0.02274
# [200]	test-logloss:0.02273
# [210]	test-logloss:0.02272
# [220]	test-logloss:0.02272
# [230]	test-logloss:0.02272
# [240]	test-logloss:0.02271
# [250]	test-logloss:0.02270
# [260]	test-logloss:0.02270
# [270]	test-logloss:0.02269
# [280]	test-logloss:0.02269
# [290]	test-logloss:0.02269
# [300]	test-logloss:0.02270
# [310]	test-logloss:0.02269
# [320]	test-logloss:0.02269
# [325]	test-logloss:0.02269
# iseed: 1
# [0]	test-logloss:0.60037
# [10]	test-logloss:0.18955
# [20]	test-logloss:0.07812
# [30]	test-logloss:0.04152
# [40]	test-logloss:0.02913
# [50]	test-logloss:0.02500
# [60]	test-logloss:0.02366
# [70]	test-logloss:0.02322
# [80]	test-logloss:0.02304
# [90]	test-logloss:0.02295
# [100]	test-logloss:0.02289
# [110]	test-logloss:0.02286
# [120]	test-logloss:0.02284
# [130]	test-logloss:0.02282
# [140]	test-logloss:0.02280
# [150]	test-logloss:0.02279
# [160]	test-logloss:0.02278
# [170]	test-logloss:0.02277
# [180]	test-logloss:0.02276
# [190]	test-logloss:0.02276
# [200]	test-logloss:0.02275
# [210]	test-logloss:0.02274
# [220]	test-logloss:0.02274
# [230]	test-logloss:0.02273
# [240]	test-logloss:0.02273
# [250]	test-logloss:0.02273
# [260]	test-logloss:0.02273
# [270]	test-logloss:0.02273
# [280]	test-logloss:0.02272
# [290]	test-logloss:0.02272
# [300]	test-logloss:0.02271
# [310]	test-logloss:0.02271
# [320]	test-logloss:0.02271
# [330]	test-logloss:0.02271
# [340]	test-logloss:0.02271
# [350]	test-logloss:0.02271
# [360]	test-logloss:0.02271
# [370]	test-logloss:0.02271
# [380]	test-logloss:0.02271
# [390]	test-logloss:0.02270
# [400]	test-logloss:0.02270
# [410]	test-logloss:0.02270
# [420]	test-logloss:0.02270
# [430]	test-logloss:0.02270
# [440]	test-logloss:0.02270
# [450]	test-logloss:0.02270
# [460]	test-logloss:0.02270
# [470]	test-logloss:0.02270
# [480]	test-logloss:0.02270
# [490]	test-logloss:0.02270
# [500]	test-logloss:0.02271
# [510]	test-logloss:0.02271
# [514]	test-logloss:0.02271
# iseed: 2
# [0]	test-logloss:0.60044
# [10]	test-logloss:0.18949
# [20]	test-logloss:0.07812
# [30]	test-logloss:0.04151
# [40]	test-logloss:0.02915
# [50]	test-logloss:0.02500
# [60]	test-logloss:0.02368
# [70]	test-logloss:0.02321
# [80]	test-logloss:0.02305
# [90]	test-logloss:0.02296
# [100]	test-logloss:0.02290
# [110]	test-logloss:0.02287
# [120]	test-logloss:0.02285
# [130]	test-logloss:0.02283
# [140]	test-logloss:0.02281
# [150]	test-logloss:0.02280
# [160]	test-logloss:0.02278
# [170]	test-logloss:0.02277
# [180]	test-logloss:0.02276
# [190]	test-logloss:0.02275
# [200]	test-logloss:0.02275
# [210]	test-logloss:0.02274
# [220]	test-logloss:0.02273
# [230]	test-logloss:0.02273
# [240]	test-logloss:0.02273
# [250]	test-logloss:0.02272
# [260]	test-logloss:0.02272
# [270]	test-logloss:0.02272
# [280]	test-logloss:0.02272
# [290]	test-logloss:0.02272
# [300]	test-logloss:0.02272
# [310]	test-logloss:0.02272
# [320]	test-logloss:0.02272
# [330]	test-logloss:0.02272
# [340]	test-logloss:0.02271
# [350]	test-logloss:0.02271
# [360]	test-logloss:0.02271
# [370]	test-logloss:0.02271
# [380]	test-logloss:0.02271
# [390]	test-logloss:0.02271
# [400]	test-logloss:0.02271
# [410]	test-logloss:0.02271
# [420]	test-logloss:0.02271
# [430]	test-logloss:0.02271
# [437]	test-logloss:0.02271
# 0.6775876790740331
# 0.6731358492589878
# ['./data_folds/fold_0/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_0/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_1/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_2/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_0.parquet', './data_folds/fold_3/split/chunks_c_2/orders/chunk_1.parquet', './data_folds/fold_4/split/chunks_c_2/orders/chunk_0.parquet']
# ./data_folds/fold_4/split/chunks_c_2/orders/chunk_1.parquet
# (17034139, 171)
# Recall Train: 0.788140558626485
# Recall Test: 0.7282983891587829
# iseed: 0
# [0]	test-logloss:0.60039
# [10]	test-logloss:0.18961
# [20]	test-logloss:0.07822
# [30]	test-logloss:0.04160
# [40]	test-logloss:0.02920
# [50]	test-logloss:0.02506
# [60]	test-logloss:0.02372
# [70]	test-logloss:0.02327
# [80]	test-logloss:0.02309
# [90]	test-logloss:0.02300
# [100]	test-logloss:0.02295
# [110]	test-logloss:0.02292
# [120]	test-logloss:0.02289
# [130]	test-logloss:0.02288
# [140]	test-logloss:0.02286
# [150]	test-logloss:0.02284
# [160]	test-logloss:0.02283
# [170]	test-logloss:0.02282
# [180]	test-logloss:0.02281
# [190]	test-logloss:0.02281
# [200]	test-logloss:0.02280
# [210]	test-logloss:0.02279
# [220]	test-logloss:0.02279
# [230]	test-logloss:0.02278
# [240]	test-logloss:0.02278
# [250]	test-logloss:0.02278
# [260]	test-logloss:0.02278
# [270]	test-logloss:0.02277
# [280]	test-logloss:0.02277
# [290]	test-logloss:0.02276
# [300]	test-logloss:0.02276
# [310]	test-logloss:0.02276
# [320]	test-logloss:0.02276
# [330]	test-logloss:0.02275
# [340]	test-logloss:0.02275
# [350]	test-logloss:0.02275
# [360]	test-logloss:0.02275
# [370]	test-logloss:0.02275
# [380]	test-logloss:0.02275
# [390]	test-logloss:0.02275
# [400]	test-logloss:0.02275
# [410]	test-logloss:0.02275
# [420]	test-logloss:0.02275
# [430]	test-logloss:0.02275
# [433]	test-logloss:0.02275
# iseed: 1
# [0]	test-logloss:0.60038
# [10]	test-logloss:0.18960
# [20]	test-logloss:0.07817
# [30]	test-logloss:0.04157
# [40]	test-logloss:0.02917
# [50]	test-logloss:0.02505
# [60]	test-logloss:0.02370
# [70]	test-logloss:0.02326
# [80]	test-logloss:0.02309
# [90]	test-logloss:0.02300
# [100]	test-logloss:0.02294
# [110]	test-logloss:0.02291
# [120]	test-logloss:0.02288
# [130]	test-logloss:0.02286
# [140]	test-logloss:0.02283
# [150]	test-logloss:0.02282
# [160]	test-logloss:0.02281
# [170]	test-logloss:0.02280
# [180]	test-logloss:0.02279
# [190]	test-logloss:0.02279
# [200]	test-logloss:0.02278
# [210]	test-logloss:0.02277
# [220]	test-logloss:0.02277
# [230]	test-logloss:0.02277
# [240]	test-logloss:0.02277
# [250]	test-logloss:0.02277
# [260]	test-logloss:0.02277
# [270]	test-logloss:0.02276
# [280]	test-logloss:0.02276
# [290]	test-logloss:0.02276
# [300]	test-logloss:0.02276
# [310]	test-logloss:0.02276
# [320]	test-logloss:0.02276
# [330]	test-logloss:0.02276
# [340]	test-logloss:0.02276
# [350]	test-logloss:0.02276
# [351]	test-logloss:0.02276
# iseed: 2
# [0]	test-logloss:0.60044
# [10]	test-logloss:0.18953
# [20]	test-logloss:0.07816
# [30]	test-logloss:0.04156
# [40]	test-logloss:0.02919
# [50]	test-logloss:0.02504
# [60]	test-logloss:0.02372
# [70]	test-logloss:0.02325
# [80]	test-logloss:0.02309
# [90]	test-logloss:0.02300
# [100]	test-logloss:0.02295
# [110]	test-logloss:0.02292
# [120]	test-logloss:0.02290
# [130]	test-logloss:0.02288
# [140]	test-logloss:0.02287
# [150]	test-logloss:0.02286
# [160]	test-logloss:0.02285
# [170]	test-logloss:0.02284
# [180]	test-logloss:0.02283
# [190]	test-logloss:0.02282
# [200]	test-logloss:0.02281
# [210]	test-logloss:0.02281
# [220]	test-logloss:0.02281
# [230]	test-logloss:0.02280
# [240]	test-logloss:0.02280
# [250]	test-logloss:0.02279
# [260]	test-logloss:0.02279
# [270]	test-logloss:0.02279
# [280]	test-logloss:0.02279
# [290]	test-logloss:0.02279
# [300]	test-logloss:0.02278
# [310]	test-logloss:0.02278
# [320]	test-logloss:0.02278
# [330]	test-logloss:0.02278
# [340]	test-logloss:0.02278
# [350]	test-logloss:0.02278
# [360]	test-logloss:0.02278
# [370]	test-logloss:0.02278
# [373]	test-logloss:0.02278
# 0.6714963456853442
# 0.6729713298657686
# CPU times: user 1h 40min 49s, sys: 13min 46s, total: 1h 54min 35s
# Wall time: 57min 11s

# %%
import numpy as np

np.mean(model_bests), np.std(model_bests), np.min(model_bests), np.max(model_bests)
# Out:
# (345.23333333333335, 45.05528702481972, 275, 464)
