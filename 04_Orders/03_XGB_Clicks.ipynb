# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import cudf
import glob
import gc

import pandas as pd

from tqdm import tqdm

# %%
def calc_recall(sub, ty='clicks', file='./data/xgb_train_y.parquet'):
    sub = sub.sort_values(['session', 'score'], ascending=[True, False])
    sub['dummy'] = 1
    sub['rank'] = sub.groupby(['session']).dummy.cumsum()
    sub.drop(['dummy'], axis=1, inplace=True)
    sub = sub[sub['rank']<21]
    sub = sub[['session', 'cand']]
    sub.columns = ['session', 'aid']
    test_labels = cudf.read_parquet(file)
    test_labels = test_labels[test_labels['type']==ty]
    test_labels = test_labels.merge(
        test_labels.groupby(['session', 'type']).count().reset_index().rename(columns={'aid': 'no_gt'}),
        how='left',
        on=['session', 'type']
    )
    sub['target'] = 1
    sub.columns = ['session', 'aid', 'target']
    test_labels = test_labels.merge(
        sub[['session', 'aid', 'target']].drop_duplicates(['session', 'aid']),
        how='left',
        on=['session', 'aid']

    )
    test_labels['target'] = test_labels['target'].fillna(0)
    test_labels = test_labels[test_labels['session'].isin(sub['session'])]
    test_labels = test_labels.groupby(['session', 'aid']).agg({'no_gt': 'min', 'target': 'sum'}).reset_index()
    recall = test_labels.target.sum()/test_labels.groupby(['session']).no_gt.min().clip(0,20).sum()
    print(recall)
    return(recall, test_labels.target.sum(), test_labels.groupby(['session']).no_gt.min().clip(0,20).sum())

# %%
# !ls ./data/split/chunks
# Out:
# carts  clicks  orders

# %%
import xgboost as xgb

xgb_parms = { 
    'max_depth':8, 
    'learning_rate':0.1, 
    'subsample':0.8,
    'colsample_bytree':0.3, 
    'eval_metric':'logloss',
    'objective':'binary:logistic',
    'tree_method':'gpu_hist' 
}

bl_sub = True
bl_pos = True
outputfolder = '24_XGB_Rerun_RedruceCandidate_DifferentWeights_Folds_ChrisCo_SameDay_v9'
no_trees = 394

# %%
ty = 'clicks'
labels = cudf.read_parquet('./data/xgb_train_y.parquet')
labels.columns = ['session', 'cand', 'type']
labels['target'] = 1

# %%
files = sorted(glob.glob('./data/split/chunks/' + ty + '/chunk*.parquet'))
files
# Out:
# ['./data/split/chunks/clicks/chunk_0.parquet',
#  './data/split/chunks/clicks/chunk_1.parquet']

# %%
[y for x in [
    sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
    for igfold2 in range(0,5)
] for y in x ]
# Out:
# ['./data_folds/fold_0/split/chunks/clicks/chunk_0.parquet',
#  './data_folds/fold_0/split/chunks/clicks/chunk_1.parquet',
#  './data_folds/fold_1/split/chunks/clicks/chunk_0.parquet',
#  './data_folds/fold_1/split/chunks/clicks/chunk_1.parquet',
#  './data_folds/fold_2/split/chunks/clicks/chunk_0.parquet',
#  './data_folds/fold_2/split/chunks/clicks/chunk_1.parquet',
#  './data_folds/fold_3/split/chunks/clicks/chunk_0.parquet',
#  './data_folds/fold_3/split/chunks/clicks/chunk_1.parquet',
#  './data_folds/fold_4/split/chunks/clicks/chunk_0.parquet',
#  './data_folds/fold_4/split/chunks/clicks/chunk_1.parquet']

# %%
session_filter = labels[(labels['type']=='carts')|(labels['type']=='orders')]['session'].drop_duplicates().to_pandas().tolist()

# %%
ingore_cols = []

# %%
# %%time

models = []
hist_recall = []
total_no_hit = 0
total_no_gt = 0
for igfold in range(1):
    files = ['x', 'y', 'z', 'zz', 'zzz']
    print(files)
    for ifile, file in enumerate(files):
        if bl_sub:
            if ty == 'clicks':
                test_files = []
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
            elif ty == 'carts':
                test_files = []
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
            elif ty == 'orders':
                test_files = []
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]]
            else:
                assert 0!=0
            
            train_files = sorted([
                y for x in [
                    sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
                    for igfold2 in range(0,5)
                ] for y in x
            ])
            
            step=2
            train_files_list = []
            for i in range(0, len(train_files), step):
                x = i
                train_files_list.append(train_files[x:x+step])
            train_files = train_files_list[ifile]
            print(train_files)
            
            if ty == 'clicks':
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
            elif ty == 'carts':
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
            elif ty == 'orders':
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
            df_train = df_train[~(df_train['session'].isin(session_filter))]
        else:
            if ty == 'clicks':
                test_files = files[ifile]
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
            elif ty == 'carts':
                test_files = files[ifile]
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
            elif ty == 'orders':
                test_files = files[ifile]
                train_files = [files[x] for x in [(ifile+i+1)%len(files) for i in range(len(files))]][0:1]
            else:
                assert 0!=0
            
            train_files = [
                y for x in [
                    sorted(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + ty + '/chunk*.parquet'))
                    for igfold2 in range(0,5)
                ] for y in x if y not in test_files]
            
            if ty == 'clicks':
                df_test = pd.read_parquet(test_files)
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])
            elif ty == 'carts':
                df_test = cudf.read_parquet(test_files)
                df_train = cudf.concat([
                    cudf.read_parquet(x) for x in train_files
                ])
            elif ty == 'orders':
                df_test = pd.read_parquet(test_files)
                df_train = pd.concat([
                    pd.read_parquet(x) for x in train_files
                ])

        print(train_files)
        print(test_files)

        if bl_pos:
            df_train = df_train[df_train['session'].isin(
                df_train[df_train['target']==1]['session'].drop_duplicates().values
            )]

        train_cols = [x for x in df_train.columns if x not in [
            'session', 'cand', 'target', 'target_clicks', 'target_carts', 'target_orders'
        ] + ingore_cols]

        print('Recall Train: ' + str(df_train[df_train['target']==1].shape[0]/labels[
        (labels['session'].isin(df_train['session'].drop_duplicates()))&(labels['type']==ty)
    ].shape[0]))
        if not bl_sub:
            print('Recall Test: ' + str(df_test[df_test['target']==1].shape[0]/labels[
            (labels['session'].isin(df_test['session'].drop_duplicates()))&(labels['type']==ty)
        ].shape[0]))

        dtrain = xgb.DMatrix(data=df_train[train_cols].values,label=df_train['target'].values)
        if not bl_sub:
            dtest =  xgb.DMatrix(data=df_test[train_cols].values, label=df_test['target'].values)
            df_test['score'] = 0.0

        del df_train
        gc.collect()

        for iseed in range(no_seeds):
            print('iseed: ' + str(iseed))
            xgb_parms['seed'] = iseed
            if bl_sub:
                model = xgb.train(
                    xgb_parms, 
                    dtrain=dtrain,
                    evals=[(dtrain,'train')],
                    num_boost_round=no_trees,
                    verbose_eval=10
                )
            else:
                model = xgb.train(
                    xgb_parms, 
                    dtrain=dtrain,
                    evals=[(dtest,'test')],
                    num_boost_round=no_trees,
                    verbose_eval=10,
                    early_stopping_rounds=50
                )
                df_test['score'] += model.predict(dtest)
            models.append(model)
        del dtrain
        gc.collect()
# Out:
# ['x', 'y', 'z', 'zz', 'zzz']
# ['./data_folds/fold_0/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_0/split/chunks/clicks/chunk_1.parquet']
# ['./data_folds/fold_0/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_0/split/chunks/clicks/chunk_1.parquet']
# []
# Recall Train: 1.0
# iseed: 0
# [0]	train-logloss:0.60190
# [10]	train-logloss:0.19911
# [20]	train-logloss:0.09192
# [30]	train-logloss:0.05802
# [40]	train-logloss:0.04712
# [50]	train-logloss:0.04363
# [60]	train-logloss:0.04245
# [70]	train-logloss:0.04196
# [80]	train-logloss:0.04170
# [90]	train-logloss:0.04152
# [100]	train-logloss:0.04138
# [110]	train-logloss:0.04126
# [120]	train-logloss:0.04114
# [130]	train-logloss:0.04104
# [140]	train-logloss:0.04094
# [150]	train-logloss:0.04085
# [160]	train-logloss:0.04077
# [170]	train-logloss:0.04069
# [180]	train-logloss:0.04060
# [190]	train-logloss:0.04051
# [200]	train-logloss:0.04043
# [210]	train-logloss:0.04036
# [220]	train-logloss:0.04029
# [230]	train-logloss:0.04023
# [240]	train-logloss:0.04017
# [250]	train-logloss:0.04009
# [260]	train-logloss:0.04003
# [270]	train-logloss:0.03996
# [280]	train-logloss:0.03991
# [290]	train-logloss:0.03984
# [300]	train-logloss:0.03978
# [310]	train-logloss:0.03972
# [320]	train-logloss:0.03966
# [330]	train-logloss:0.03961
# [340]	train-logloss:0.03954
# [350]	train-logloss:0.03948
# [360]	train-logloss:0.03942
# [370]	train-logloss:0.03937
# [380]	train-logloss:0.03931
# [390]	train-logloss:0.03926
# [393]	train-logloss:0.03924
# iseed: 1
# [0]	train-logloss:0.60189
# [10]	train-logloss:0.19907
# [20]	train-logloss:0.09199
# [30]	train-logloss:0.05807
# [40]	train-logloss:0.04719
# [50]	train-logloss:0.04368
# [60]	train-logloss:0.04250
# [70]	train-logloss:0.04203
# [80]	train-logloss:0.04173
# [90]	train-logloss:0.04154
# [100]	train-logloss:0.04139
# [110]	train-logloss:0.04127
# [120]	train-logloss:0.04115
# [130]	train-logloss:0.04106
# [140]	train-logloss:0.04095
# [150]	train-logloss:0.04086
# [160]	train-logloss:0.04078
# [170]	train-logloss:0.04071
# [180]	train-logloss:0.04064
# [190]	train-logloss:0.04056
# [200]	train-logloss:0.04048
# [210]	train-logloss:0.04040
# [220]	train-logloss:0.04032
# [230]	train-logloss:0.04025
# [240]	train-logloss:0.04018
# [250]	train-logloss:0.04012
# [260]	train-logloss:0.04006
# [270]	train-logloss:0.04000
# [280]	train-logloss:0.03994
# [290]	train-logloss:0.03989
# [300]	train-logloss:0.03983
# [310]	train-logloss:0.03977
# [320]	train-logloss:0.03971
# [330]	train-logloss:0.03964
# [340]	train-logloss:0.03958
# [350]	train-logloss:0.03952
# [360]	train-logloss:0.03946
# [370]	train-logloss:0.03941
# [380]	train-logloss:0.03934
# [390]	train-logloss:0.03929
# [393]	train-logloss:0.03927
# iseed: 2
# [0]	train-logloss:0.60188
# [10]	train-logloss:0.19911
# [20]	train-logloss:0.09202
# [30]	train-logloss:0.05804
# [40]	train-logloss:0.04714
# [50]	train-logloss:0.04362
# [60]	train-logloss:0.04244
# [70]	train-logloss:0.04196
# [80]	train-logloss:0.04170
# [90]	train-logloss:0.04151
# [100]	train-logloss:0.04137
# [110]	train-logloss:0.04126
# [120]	train-logloss:0.04116
# [130]	train-logloss:0.04105
# [140]	train-logloss:0.04096
# [150]	train-logloss:0.04087
# [160]	train-logloss:0.04077
# [170]	train-logloss:0.04069
# [180]	train-logloss:0.04060
# [190]	train-logloss:0.04053
# [200]	train-logloss:0.04046
# [210]	train-logloss:0.04038
# [220]	train-logloss:0.04031
# [230]	train-logloss:0.04024
# [240]	train-logloss:0.04017
# [250]	train-logloss:0.04011
# [260]	train-logloss:0.04006
# [270]	train-logloss:0.04000
# [280]	train-logloss:0.03993
# [290]	train-logloss:0.03986
# [300]	train-logloss:0.03981
# [310]	train-logloss:0.03974
# [320]	train-logloss:0.03967
# [330]	train-logloss:0.03961
# [340]	train-logloss:0.03956
# [350]	train-logloss:0.03950
# [360]	train-logloss:0.03944
# [370]	train-logloss:0.03938
# [380]	train-logloss:0.03932
# [390]	train-logloss:0.03927
# [393]	train-logloss:0.03925
# ['./data_folds/fold_1/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_1/split/chunks/clicks/chunk_1.parquet']
# ['./data_folds/fold_1/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_1/split/chunks/clicks/chunk_1.parquet']
# []
# Recall Train: 1.0
# iseed: 0
# [0]	train-logloss:0.60192
# [10]	train-logloss:0.19922
# [20]	train-logloss:0.09209
# [30]	train-logloss:0.05821
# [40]	train-logloss:0.04732
# [50]	train-logloss:0.04383
# [60]	train-logloss:0.04264
# [70]	train-logloss:0.04215
# [80]	train-logloss:0.04188
# [90]	train-logloss:0.04170
# [100]	train-logloss:0.04156
# [110]	train-logloss:0.04143
# [120]	train-logloss:0.04132
# [130]	train-logloss:0.04121
# [140]	train-logloss:0.04112
# [150]	train-logloss:0.04102
# [160]	train-logloss:0.04094
# [170]	train-logloss:0.04087
# [180]	train-logloss:0.04078
# [190]	train-logloss:0.04069
# [200]	train-logloss:0.04062
# [210]	train-logloss:0.04055
# [220]	train-logloss:0.04047
# [230]	train-logloss:0.04041
# [240]	train-logloss:0.04034
# [250]	train-logloss:0.04027
# [260]	train-logloss:0.04020
# [270]	train-logloss:0.04015
# [280]	train-logloss:0.04008
# [290]	train-logloss:0.04001
# [300]	train-logloss:0.03995
# [310]	train-logloss:0.03989
# [320]	train-logloss:0.03983
# [330]	train-logloss:0.03977
# [340]	train-logloss:0.03971
# [350]	train-logloss:0.03966
# [360]	train-logloss:0.03961
# [370]	train-logloss:0.03955
# [380]	train-logloss:0.03948
# [390]	train-logloss:0.03942
# [393]	train-logloss:0.03940
# iseed: 1
# [0]	train-logloss:0.60191
# [10]	train-logloss:0.19920
# [20]	train-logloss:0.09216
# [30]	train-logloss:0.05827
# [40]	train-logloss:0.04739
# [50]	train-logloss:0.04389
# [60]	train-logloss:0.04272
# [70]	train-logloss:0.04225
# [80]	train-logloss:0.04194
# [90]	train-logloss:0.04177
# [100]	train-logloss:0.04160
# [110]	train-logloss:0.04148
# [120]	train-logloss:0.04136
# [130]	train-logloss:0.04126
# [140]	train-logloss:0.04115
# [150]	train-logloss:0.04105
# [160]	train-logloss:0.04097
# [170]	train-logloss:0.04089
# [180]	train-logloss:0.04082
# [190]	train-logloss:0.04074
# [200]	train-logloss:0.04066
# [210]	train-logloss:0.04059
# [220]	train-logloss:0.04052
# [230]	train-logloss:0.04046
# [240]	train-logloss:0.04038
# [250]	train-logloss:0.04032
# [260]	train-logloss:0.04027
# [270]	train-logloss:0.04021
# [280]	train-logloss:0.04015
# [290]	train-logloss:0.04008
# [300]	train-logloss:0.04002
# [310]	train-logloss:0.03997
# [320]	train-logloss:0.03990
# [330]	train-logloss:0.03984
# [340]	train-logloss:0.03977
# [350]	train-logloss:0.03971
# [360]	train-logloss:0.03965
# [370]	train-logloss:0.03959
# [380]	train-logloss:0.03952
# [390]	train-logloss:0.03947
# [393]	train-logloss:0.03945
# iseed: 2
# [0]	train-logloss:0.60190
# [10]	train-logloss:0.19924
# [20]	train-logloss:0.09219
# [30]	train-logloss:0.05824
# [40]	train-logloss:0.04734
# [50]	train-logloss:0.04381
# [60]	train-logloss:0.04263
# [70]	train-logloss:0.04217
# [80]	train-logloss:0.04190
# [90]	train-logloss:0.04171
# [100]	train-logloss:0.04157
# [110]	train-logloss:0.04145
# [120]	train-logloss:0.04133
# [130]	train-logloss:0.04123
# [140]	train-logloss:0.04113
# [150]	train-logloss:0.04104
# [160]	train-logloss:0.04096
# [170]	train-logloss:0.04087
# [180]	train-logloss:0.04079
# [190]	train-logloss:0.04072
# [200]	train-logloss:0.04065
# [210]	train-logloss:0.04057
# [220]	train-logloss:0.04050
# [230]	train-logloss:0.04043
# [240]	train-logloss:0.04037
# [250]	train-logloss:0.04030
# [260]	train-logloss:0.04023
# [270]	train-logloss:0.04017
# [280]	train-logloss:0.04011
# [290]	train-logloss:0.04005
# [300]	train-logloss:0.03999
# [310]	train-logloss:0.03993
# [320]	train-logloss:0.03987
# [330]	train-logloss:0.03980
# [340]	train-logloss:0.03974
# [350]	train-logloss:0.03969
# [360]	train-logloss:0.03964
# [370]	train-logloss:0.03958
# [380]	train-logloss:0.03954
# [390]	train-logloss:0.03948
# [393]	train-logloss:0.03946
# ['./data_folds/fold_2/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_2/split/chunks/clicks/chunk_1.parquet']
# ['./data_folds/fold_2/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_2/split/chunks/clicks/chunk_1.parquet']
# []
# Recall Train: 1.0
# iseed: 0
# [0]	train-logloss:0.60191
# [10]	train-logloss:0.19915
# [20]	train-logloss:0.09199
# [30]	train-logloss:0.05810
# [40]	train-logloss:0.04720
# [50]	train-logloss:0.04370
# [60]	train-logloss:0.04250
# [70]	train-logloss:0.04202
# [80]	train-logloss:0.04175
# [90]	train-logloss:0.04157
# [100]	train-logloss:0.04144
# [110]	train-logloss:0.04131
# [120]	train-logloss:0.04120
# [130]	train-logloss:0.04110
# [140]	train-logloss:0.04100
# [150]	train-logloss:0.04092
# [160]	train-logloss:0.04084
# [170]	train-logloss:0.04076
# [180]	train-logloss:0.04067
# [190]	train-logloss:0.04059
# [200]	train-logloss:0.04051
# [210]	train-logloss:0.04045
# [220]	train-logloss:0.04038
# [230]	train-logloss:0.04032
# [240]	train-logloss:0.04026
# [250]	train-logloss:0.04019
# [260]	train-logloss:0.04013
# [270]	train-logloss:0.04006
# [280]	train-logloss:0.03999
# [290]	train-logloss:0.03992
# [300]	train-logloss:0.03988
# [310]	train-logloss:0.03981
# [320]	train-logloss:0.03975
# [330]	train-logloss:0.03968
# [340]	train-logloss:0.03963
# [350]	train-logloss:0.03957
# [360]	train-logloss:0.03950
# [370]	train-logloss:0.03943
# [380]	train-logloss:0.03937
# [390]	train-logloss:0.03931
# [393]	train-logloss:0.03930
# iseed: 1
# [0]	train-logloss:0.60189
# [10]	train-logloss:0.19913
# [20]	train-logloss:0.09206
# [30]	train-logloss:0.05815
# [40]	train-logloss:0.04727
# [50]	train-logloss:0.04376
# [60]	train-logloss:0.04258
# [70]	train-logloss:0.04210
# [80]	train-logloss:0.04180
# [90]	train-logloss:0.04162
# [100]	train-logloss:0.04145
# [110]	train-logloss:0.04133
# [120]	train-logloss:0.04121
# [130]	train-logloss:0.04112
# [140]	train-logloss:0.04101
# [150]	train-logloss:0.04092
# [160]	train-logloss:0.04084
# [170]	train-logloss:0.04076
# [180]	train-logloss:0.04070
# [190]	train-logloss:0.04063
# [200]	train-logloss:0.04055
# [210]	train-logloss:0.04049
# [220]	train-logloss:0.04041
# [230]	train-logloss:0.04034
# [240]	train-logloss:0.04027
# [250]	train-logloss:0.04020
# [260]	train-logloss:0.04013
# [270]	train-logloss:0.04006
# [280]	train-logloss:0.03999
# [290]	train-logloss:0.03994
# [300]	train-logloss:0.03987
# [310]	train-logloss:0.03981
# [320]	train-logloss:0.03975
# [330]	train-logloss:0.03968
# [340]	train-logloss:0.03962
# [350]	train-logloss:0.03956
# [360]	train-logloss:0.03950
# [370]	train-logloss:0.03944
# [380]	train-logloss:0.03938
# [390]	train-logloss:0.03933
# [393]	train-logloss:0.03931
# iseed: 2
# [0]	train-logloss:0.60188
# [10]	train-logloss:0.19916
# [20]	train-logloss:0.09209
# [30]	train-logloss:0.05812
# [40]	train-logloss:0.04722
# [50]	train-logloss:0.04369
# [60]	train-logloss:0.04251
# [70]	train-logloss:0.04204
# [80]	train-logloss:0.04176
# [90]	train-logloss:0.04157
# [100]	train-logloss:0.04144
# [110]	train-logloss:0.04132
# [120]	train-logloss:0.04122
# [130]	train-logloss:0.04112
# [140]	train-logloss:0.04103
# [150]	train-logloss:0.04095
# [160]	train-logloss:0.04086
# [170]	train-logloss:0.04077
# [180]	train-logloss:0.04069
# [190]	train-logloss:0.04061
# [200]	train-logloss:0.04054
# [210]	train-logloss:0.04047
# [220]	train-logloss:0.04041
# [230]	train-logloss:0.04033
# [240]	train-logloss:0.04026
# [250]	train-logloss:0.04020
# [260]	train-logloss:0.04014
# [270]	train-logloss:0.04008
# [280]	train-logloss:0.04001
# [290]	train-logloss:0.03995
# [300]	train-logloss:0.03989
# [310]	train-logloss:0.03982
# [320]	train-logloss:0.03977
# [330]	train-logloss:0.03970
# [340]	train-logloss:0.03963
# [350]	train-logloss:0.03958
# [360]	train-logloss:0.03952
# [370]	train-logloss:0.03945
# [380]	train-logloss:0.03939
# [390]	train-logloss:0.03933
# [393]	train-logloss:0.03931
# ['./data_folds/fold_3/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_3/split/chunks/clicks/chunk_1.parquet']
# ['./data_folds/fold_3/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_3/split/chunks/clicks/chunk_1.parquet']
# []
# Recall Train: 1.0
# iseed: 0
# [0]	train-logloss:0.60191
# [10]	train-logloss:0.19916
# [20]	train-logloss:0.09201
# [30]	train-logloss:0.05812
# [40]	train-logloss:0.04722
# [50]	train-logloss:0.04373
# [60]	train-logloss:0.04254
# [70]	train-logloss:0.04205
# [80]	train-logloss:0.04177
# [90]	train-logloss:0.04159
# [100]	train-logloss:0.04145
# [110]	train-logloss:0.04133
# [120]	train-logloss:0.04122
# [130]	train-logloss:0.04112
# [140]	train-logloss:0.04103
# [150]	train-logloss:0.04094
# [160]	train-logloss:0.04086
# [170]	train-logloss:0.04077
# [180]	train-logloss:0.04068
# [190]	train-logloss:0.04060
# [200]	train-logloss:0.04054
# [210]	train-logloss:0.04047
# [220]	train-logloss:0.04038
# [230]	train-logloss:0.04031
# [240]	train-logloss:0.04026
# [250]	train-logloss:0.04018
# [260]	train-logloss:0.04011
# [270]	train-logloss:0.04004
# [280]	train-logloss:0.03997
# [290]	train-logloss:0.03991
# [300]	train-logloss:0.03984
# [310]	train-logloss:0.03979
# [320]	train-logloss:0.03973
# [330]	train-logloss:0.03967
# [340]	train-logloss:0.03961
# [350]	train-logloss:0.03955
# [360]	train-logloss:0.03948
# [370]	train-logloss:0.03941
# [380]	train-logloss:0.03936
# [390]	train-logloss:0.03931
# [393]	train-logloss:0.03929
# iseed: 1
# [0]	train-logloss:0.60190
# [10]	train-logloss:0.19914
# [20]	train-logloss:0.09207
# [30]	train-logloss:0.05816
# [40]	train-logloss:0.04728
# [50]	train-logloss:0.04377
# [60]	train-logloss:0.04259
# [70]	train-logloss:0.04211
# [80]	train-logloss:0.04181
# [90]	train-logloss:0.04163
# [100]	train-logloss:0.04148
# [110]	train-logloss:0.04136
# [120]	train-logloss:0.04125
# [130]	train-logloss:0.04116
# [140]	train-logloss:0.04106
# [150]	train-logloss:0.04097
# [160]	train-logloss:0.04089
# [170]	train-logloss:0.04081
# [180]	train-logloss:0.04073
# [190]	train-logloss:0.04067
# [200]	train-logloss:0.04059
# [210]	train-logloss:0.04051
# [220]	train-logloss:0.04044
# [230]	train-logloss:0.04036
# [240]	train-logloss:0.04029
# [250]	train-logloss:0.04022
# [260]	train-logloss:0.04015
# [270]	train-logloss:0.04009
# [280]	train-logloss:0.04002
# [290]	train-logloss:0.03996
# [300]	train-logloss:0.03990
# [310]	train-logloss:0.03983
# [320]	train-logloss:0.03976
# [330]	train-logloss:0.03970
# [340]	train-logloss:0.03963
# [350]	train-logloss:0.03958
# [360]	train-logloss:0.03952
# [370]	train-logloss:0.03946
# [380]	train-logloss:0.03941
# [390]	train-logloss:0.03935
# [393]	train-logloss:0.03933
# iseed: 2
# [0]	train-logloss:0.60189
# [10]	train-logloss:0.19916
# [20]	train-logloss:0.09211
# [30]	train-logloss:0.05814
# [40]	train-logloss:0.04723
# [50]	train-logloss:0.04371
# [60]	train-logloss:0.04252
# [70]	train-logloss:0.04205
# [80]	train-logloss:0.04178
# [90]	train-logloss:0.04160
# [100]	train-logloss:0.04147
# [110]	train-logloss:0.04134
# [120]	train-logloss:0.04124
# [130]	train-logloss:0.04114
# [140]	train-logloss:0.04105
# [150]	train-logloss:0.04094
# [160]	train-logloss:0.04087
# [170]	train-logloss:0.04078
# [180]	train-logloss:0.04070
# [190]	train-logloss:0.04064
# [200]	train-logloss:0.04057
# [210]	train-logloss:0.04050
# [220]	train-logloss:0.04043
# [230]	train-logloss:0.04036
# [240]	train-logloss:0.04029
# [250]	train-logloss:0.04023
# [260]	train-logloss:0.04016
# [270]	train-logloss:0.04009
# [280]	train-logloss:0.04003
# [290]	train-logloss:0.03996
# [300]	train-logloss:0.03990
# [310]	train-logloss:0.03983
# [320]	train-logloss:0.03976
# [330]	train-logloss:0.03970
# [340]	train-logloss:0.03964
# [350]	train-logloss:0.03958
# [360]	train-logloss:0.03952
# [370]	train-logloss:0.03947
# [380]	train-logloss:0.03941
# [390]	train-logloss:0.03935
# [393]	train-logloss:0.03933
# ['./data_folds/fold_4/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_4/split/chunks/clicks/chunk_1.parquet']
# ['./data_folds/fold_4/split/chunks/clicks/chunk_0.parquet', './data_folds/fold_4/split/chunks/clicks/chunk_1.parquet']
# []
# Recall Train: 1.0
# iseed: 0
# [0]	train-logloss:0.60191
# [10]	train-logloss:0.19916
# [20]	train-logloss:0.09201
# [30]	train-logloss:0.05812
# [40]	train-logloss:0.04723
# [50]	train-logloss:0.04374
# [60]	train-logloss:0.04255
# [70]	train-logloss:0.04206
# [80]	train-logloss:0.04179
# [90]	train-logloss:0.04161
# [100]	train-logloss:0.04148
# [110]	train-logloss:0.04137
# [120]	train-logloss:0.04125
# [130]	train-logloss:0.04114
# [140]	train-logloss:0.04104
# [150]	train-logloss:0.04095
# [160]	train-logloss:0.04087
# [170]	train-logloss:0.04079
# [180]	train-logloss:0.04072
# [190]	train-logloss:0.04065
# [200]	train-logloss:0.04058
# [210]	train-logloss:0.04051
# [220]	train-logloss:0.04044
# [230]	train-logloss:0.04037
# [240]	train-logloss:0.04030
# [250]	train-logloss:0.04023
# [260]	train-logloss:0.04017
# [270]	train-logloss:0.04011
# [280]	train-logloss:0.04004
# [290]	train-logloss:0.03998
# [300]	train-logloss:0.03992
# [310]	train-logloss:0.03985
# [320]	train-logloss:0.03978
# [330]	train-logloss:0.03970
# [340]	train-logloss:0.03965
# [350]	train-logloss:0.03959
# [360]	train-logloss:0.03952
# [370]	train-logloss:0.03946
# [380]	train-logloss:0.03940
# [390]	train-logloss:0.03934
# [393]	train-logloss:0.03932
# iseed: 1
# [0]	train-logloss:0.60189
# [10]	train-logloss:0.19913
# [20]	train-logloss:0.09208
# [30]	train-logloss:0.05817
# [40]	train-logloss:0.04729
# [50]	train-logloss:0.04378
# [60]	train-logloss:0.04261
# [70]	train-logloss:0.04213
# [80]	train-logloss:0.04182
# [90]	train-logloss:0.04165
# [100]	train-logloss:0.04149
# [110]	train-logloss:0.04136
# [120]	train-logloss:0.04125
# [130]	train-logloss:0.04116
# [140]	train-logloss:0.04106
# [150]	train-logloss:0.04098
# [160]	train-logloss:0.04090
# [170]	train-logloss:0.04082
# [180]	train-logloss:0.04075
# [190]	train-logloss:0.04066
# [200]	train-logloss:0.04059
# [210]	train-logloss:0.04052
# [220]	train-logloss:0.04044
# [230]	train-logloss:0.04038
# [240]	train-logloss:0.04030
# [250]	train-logloss:0.04025
# [260]	train-logloss:0.04018
# [270]	train-logloss:0.04011
# [280]	train-logloss:0.04005
# [290]	train-logloss:0.03999
# [300]	train-logloss:0.03993
# [310]	train-logloss:0.03987
# [320]	train-logloss:0.03981
# [330]	train-logloss:0.03976
# [340]	train-logloss:0.03971
# [350]	train-logloss:0.03964
# [360]	train-logloss:0.03959
# [370]	train-logloss:0.03953
# [380]	train-logloss:0.03948
# [390]	train-logloss:0.03941
# [393]	train-logloss:0.03939
# iseed: 2
# [0]	train-logloss:0.60189
# [10]	train-logloss:0.19917
# [20]	train-logloss:0.09210
# [30]	train-logloss:0.05814
# [40]	train-logloss:0.04724
# [50]	train-logloss:0.04371
# [60]	train-logloss:0.04253
# [70]	train-logloss:0.04206
# [80]	train-logloss:0.04179
# [90]	train-logloss:0.04161
# [100]	train-logloss:0.04148
# [110]	train-logloss:0.04136
# [120]	train-logloss:0.04125
# [130]	train-logloss:0.04114
# [140]	train-logloss:0.04105
# [150]	train-logloss:0.04095
# [160]	train-logloss:0.04088
# [170]	train-logloss:0.04079
# [180]	train-logloss:0.04072
# [190]	train-logloss:0.04065
# [200]	train-logloss:0.04058
# [210]	train-logloss:0.04052
# [220]	train-logloss:0.04045
# [230]	train-logloss:0.04038
# [240]	train-logloss:0.04031
# [250]	train-logloss:0.04023
# [260]	train-logloss:0.04016
# [270]	train-logloss:0.04010
# [280]	train-logloss:0.04004
# [290]	train-logloss:0.03999
# [300]	train-logloss:0.03993
# [310]	train-logloss:0.03986
# [320]	train-logloss:0.03981
# [330]	train-logloss:0.03975
# [340]	train-logloss:0.03969
# [350]	train-logloss:0.03962
# [360]	train-logloss:0.03956
# [370]	train-logloss:0.03949
# [380]	train-logloss:0.03944
# [390]	train-logloss:0.03939
# [393]	train-logloss:0.03937
# CPU times: user 42min 13s, sys: 10min 17s, total: 52min 31s
# Wall time: 31min 52s

# %%
no_seeds = len(models)
ifile = 0

# %%
for igfold2 in range(5):
    os.system('mkdir -p ' + './data_folds/fold_' + str(igfold2) + '/split/sub_c/')
    os.system('mkdir -p ' + './data_folds/fold_' + str(igfold2) + '/split/chunks_c/' + 'carts' + '/')
    os.system('mkdir -p ' + './data_folds/fold_' + str(igfold2) + '/split/chunks_c/' + 'orders' + '/')

# %% [markdown]
# Predict Carts Dataset and add click score

# %%
for igfold2 in range(5):
    if ifile==0:
        sssfiles = glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + 'carts' + '/chunk*.parquet')
    else:
        sssfiles = glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks_c/' + 'carts' + '/chunk*.parquet')
    for isubfile, sub_file in enumerate(sssfiles):
        print('isubfile: ' + str(isubfile))
        df_sub = cudf.read_parquet(sub_file).fillna(-999)
        if 'xgb_c_score' not in df_sub.columns:
            df_sub['xgb_c_score'] = 0.0
                    
        dsub = xgb.DMatrix(data=df_sub[train_cols].values)
        for iseed in range(no_seeds):
            df_sub['xgb_c_score'] = df_sub['xgb_c_score'] + models[iseed].predict(dsub)/no_seeds
        if ifile==0:
            df_sub.to_parquet(
                sub_file.replace('/chunks/', '/chunks_c/')
            )
        else:
            df_sub.to_parquet(
                sub_file
            )
        del df_sub
        gc.collect()
# Out:
# isubfile: 0
# /usr/local/lib/python3.8/dist-packages/cudf/core/single_column_frame.py:345: FutureWarning: Binary operations between host objects such as <class 'numpy.ndarray'> and <class 'cudf.core.series.Series'> are deprecated and will be removed in a future release. Please convert it to a cudf object before performing the operation.
#   warnings.warn(
# isubfile: 1
# isubfile: 0
# isubfile: 1
# isubfile: 0
# isubfile: 1
# isubfile: 0
# isubfile: 1
# isubfile: 0
# isubfile: 1
# 0

# %% [markdown]
# Predict Orders Dataset and add click score

# %%
for igfold2 in range(5):
    if ifile==0:
        sssfiles = glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + 'orders' + '/chunk*.parquet')
    else:
        sssfiles = glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks_c/' + 'orders' + '/chunk*.parquet')
    for isubfile, sub_file in enumerate(glob.glob('./data_folds/fold_' + str(igfold2) + '/split/chunks/' + 'orders' + '/chunk*.parquet')):
        print('isubfile: ' + str(isubfile))
        df_sub = cudf.read_parquet(sub_file).fillna(-999)
        if 'xgb_c_score' not in df_sub.columns:
            df_sub['xgb_c_score'] = 0.0

        dsub = xgb.DMatrix(data=df_sub[train_cols].values)
        for iseed in range(no_seeds):
            df_sub['xgb_c_score'] = df_sub['xgb_c_score'] + models[iseed].predict(dsub)/no_seeds
        if ifile==0:
            df_sub.to_parquet(
                sub_file.replace('/chunks/', '/chunks_c/')
            )
        else:
            df_sub.to_parquet(
                sub_file
            )
        del df_sub
        gc.collect()
# Out:
# isubfile: 0
# /usr/local/lib/python3.8/dist-packages/cudf/core/single_column_frame.py:345: FutureWarning: Binary operations between host objects such as <class 'numpy.ndarray'> and <class 'cudf.core.series.Series'> are deprecated and will be removed in a future release. Please convert it to a cudf object before performing the operation.
#   warnings.warn(
# isubfile: 1
# isubfile: 0
# isubfile: 1
# isubfile: 0
# isubfile: 1
# isubfile: 0
# isubfile: 1
# isubfile: 0
# isubfile: 1

# %% [markdown]
# Predict Submission Dataset and add click score

# %%
for igfold2 in [0,1,2,3,4]:
    if ifile==0:
        sssfiles = glob.glob('./data_folds/fold_' + str(igfold2) + '/split/sub/*.parquet')
    else:
        sssfiles = glob.glob('./data_folds/fold_' + str(igfold2) + '/split/sub_c/*.parquet')
    for isubfile, sub_file in enumerate(sssfiles):
        print('isubfile: ' + str(isubfile))
        df_sub = cudf.read_parquet(sub_file).fillna(-999)
        if 'xgb_c_score' not in df_sub.columns:
            df_sub['xgb_c_score'] = 0.0
        
        dsub = xgb.DMatrix(data=df_sub[train_cols].values)
        for iseed in range(no_seeds):
            df_sub['xgb_c_score'] = df_sub['xgb_c_score'] + models[iseed].predict(dsub)/no_seeds
        if ifile==0:
            df_sub.to_parquet(
                sub_file.replace('/sub/', '/sub_c/')
            )
        else:
            df_sub.to_parquet(
                sub_file
            )
        del df_sub
        gc.collect()
gc.collect()
# Out:
# isubfile: 0
# isubfile: 1
# isubfile: 2
# isubfile: 3
# isubfile: 4
# isubfile: 5
# isubfile: 6
# isubfile: 7
# isubfile: 8
# isubfile: 9
# isubfile: 10
# isubfile: 11
# isubfile: 12
# isubfile: 13
# isubfile: 14
# isubfile: 15
# isubfile: 16
# isubfile: 17
# isubfile: 18
# isubfile: 19
# isubfile: 20
# isubfile: 21
# isubfile: 22
# isubfile: 23
# isubfile: 24
# isubfile: 25
# isubfile: 26
# isubfile: 27
# isubfile: 28
# isubfile: 29
# isubfile: 30
# isubfile: 31
# isubfile: 32
# isubfile: 33
# isubfile: 34
# isubfile: 35
# isubfile: 36
# isubfile: 37
# isubfile: 38
# isubfile: 39
# isubfile: 40
# isubfile: 41
# isubfile: 42
# isubfile: 43
# isubfile: 44
# isubfile: 45
# isubfile: 46
# isubfile: 47
# isubfile: 48
# isubfile: 49
# isubfile: 50
# isubfile: 51
# isubfile: 52
# isubfile: 53
# isubfile: 54
# isubfile: 55
# isubfile: 56
# isubfile: 57
# isubfile: 58
# isubfile: 59
# isubfile: 60
# isubfile: 61
# isubfile: 62
# isubfile: 63
# isubfile: 64
# isubfile: 65
# isubfile: 66
# isubfile: 67
# isubfile: 68
# isubfile: 69
# isubfile: 70
# isubfile: 71
# isubfile: 72
# isubfile: 73
# isubfile: 74
# isubfile: 75
# isubfile: 76
# isubfile: 77
# isubfile: 78
# isubfile: 79
# isubfile: 80
# isubfile: 81
# isubfile: 82
# isubfile: 83
# isubfile: 84
# isubfile: 85
# isubfile: 86
# isubfile: 87
# isubfile: 88
# isubfile: 89
# isubfile: 90
# isubfile: 91
# isubfile: 92
# isubfile: 93
# isubfile: 94
# isubfile: 95
# isubfile: 96
# isubfile: 97
# isubfile: 98
# isubfile: 99
